# %% [markdown]
# <a href="https://colab.research.google.com/github/tsainez/examples/blob/master/python/LC_algorithm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/UCMerced-ML/LC-model-compression
# Out:
# Cloning into 'LC-model-compression'...
# remote: Enumerating objects: 166, done.
# remote: Counting objects: 100% (166/166), done.
# remote: Compressing objects: 100% (121/121), done.
# remote: Total 166 (delta 63), reused 142 (delta 42), pack-reused 0
# Receiving objects: 100% (166/166), 3.19 MiB | 17.54 MiB/s, done.
# Resolving deltas: 100% (63/63), done.

# %%
! pip3 install -e ./LC-model-compression
# Out:
# Obtaining file:///content/LC-model-compression
# Requirement already satisfied: numpy>=1.16.2 in /usr/local/lib/python3.7/dist-packages (from lc==0.1) (1.19.5)
# Requirement already satisfied: scipy>=1.2.1 in /usr/local/lib/python3.7/dist-packages (from lc==0.1) (1.4.1)
# Requirement already satisfied: torch>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from lc==0.1) (1.10.0+cu111)
# Requirement already satisfied: torchvision>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from lc==0.1) (0.11.1+cu111)
# Requirement already satisfied: scikit-learn>=0.20.2 in /usr/local/lib/python3.7/dist-packages (from lc==0.1) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.20.2->lc==0.1) (3.0.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.20.2->lc==0.1) (1.1.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.0.1->lc==0.1) (3.10.0.2)
# Requirement already satisfied: pillow!=8.3.0,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision>=0.2.2->lc==0.1) (7.1.2)
# Installing collected packages: lc
#   Running setup.py develop for lc
# Successfully installed lc-0.1

# %% [markdown]
# ## IMPORTANT!
# At this point you need to restart the runtime by doing "Runtime => Restart Runtime"

# %%
import lc
from lc.torch import ParameterTorch as Param, AsVector, AsIs
from lc.compression_types import ConstraintL0Pruning, LowRank, RankSelection, AdaptiveQuantization
from lc.models.torch import lenet300_classic, lenet300_modern_drop, lenet300_modern

import numpy as np

import torch
from torch import nn, optim
from torch.utils.data import TensorDataset, DataLoader, random_split
from torchvision import datasets
torch.set_num_threads(4)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-e1bb64a7c4f1> in <module>()
# ----> 1 import lc
#       2 from lc.torch import ParameterTorch as Param, AsVector, AsIs
#       3 from lc.compression_types import ConstraintL0Pruning, LowRank, RankSelection, AdaptiveQuantization
#       4 from lc.models.torch import lenet300_classic, lenet300_modern_drop, lenet300_modern
#       5
#
# ModuleNotFoundError: No module named 'lc'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# ## Data
# We use a subset of the MNIST dataset. The dataset contains subtracted 28x28 grayscale images with digits 0, 2, 5, 6, and 7. The images are normalized to have grayscale value 0 to 1 and then mean is subtracted.

# %%
from matplotlib import pyplot as plt
import warnings
warnings.filterwarnings('ignore')
plt.rcParams['figure.figsize'] = [10, 5]
def show_MNIST_images():
    train_data_th = datasets.MNIST(root='./datasets', download=True, train=True)
    data_train = np.array(train_data_th.data[:])
    targets = np.array(train_data_th.targets)
    images_to_show = 5
    random_indexes = np.random.randint(data_train.shape[0], size=images_to_show)
    for i,ind in enumerate(random_indexes):
        plt.subplot(1,images_to_show,i+1)
        plt.imshow(data_train[ind], cmap='gray')
        plt.xlabel(targets[ind])
        plt.xticks([])
        plt.yticks([])
show_MNIST_images()
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ./datasets/MNIST/raw/train-images-idx3-ubyte.gz
#   0%|          | 0/9912422 [00:00<?, ?it/s]
# Extracting ./datasets/MNIST/raw/train-images-idx3-ubyte.gz to ./datasets/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ./datasets/MNIST/raw/train-labels-idx1-ubyte.gz
#   0%|          | 0/28881 [00:00<?, ?it/s]
# Extracting ./datasets/MNIST/raw/train-labels-idx1-ubyte.gz to ./datasets/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ./datasets/MNIST/raw/t10k-images-idx3-ubyte.gz
#   0%|          | 0/1648877 [00:00<?, ?it/s]
# Extracting ./datasets/MNIST/raw/t10k-images-idx3-ubyte.gz to ./datasets/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ./datasets/MNIST/raw/t10k-labels-idx1-ubyte.gz
#   0%|          | 0/4542 [00:00<?, ?it/s]
# Extracting ./datasets/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./datasets/MNIST/raw

# %%
def data_loader(batch_size=2048, n_workers=4):
    train_data_th = datasets.MNIST(root='./datasets', download=True, train=True)
    test_data_th = datasets.MNIST(root='./datasets', download=True, train=False)

    # Get subset of digits that we will be using
    indices = (train_data_th.targets == 0) | (train_data_th.targets == 2) | (train_data_th.targets == 5) | (train_data_th.targets == 6) | (train_data_th.targets == 7)
    train_data, train_targets = train_data_th.data[indices], train_data_th.targets[indices]

    indices = (test_data_th.targets == 0) | (test_data_th.targets == 2) | (test_data_th.targets == 5) | (test_data_th.targets == 6) | (test_data_th.targets == 7)
    test_data, test_targets = test_data_th.data[indices], test_data_th.targets[indices]

    # Change labels to be in range 0 - C-1 so cross entropy function works
    for i, digit in enumerate([0,2,5,6,7]):
        train_targets = torch.where(train_targets == digit, i, train_targets)
        test_targets = torch.where(test_targets == digit, i, test_targets)

    data_train = np.array(train_data[:]).reshape([-1, 28 * 28]).astype(np.float32)
    data_test = np.array(test_data[:]).reshape([-1, 28 * 28]).astype(np.float32)

    data_train = (data_train / 255)
    dtrain_mean = data_train.mean(axis=0)
    data_train -= dtrain_mean
    data_test = (data_test / 255).astype(np.float32)
    data_test -= dtrain_mean

    train_data = TensorDataset(torch.from_numpy(data_train), train_targets)

    # Create validation set
    val_split = int(0.3 * len(train_data))
    train_data, val_data = random_split(train_data, [len(train_data) - val_split, val_split], generator=torch.Generator().manual_seed(1778))

    test_data = TensorDataset(torch.from_numpy(data_test), test_targets)

    train_loader = DataLoader(train_data, num_workers=n_workers, batch_size=batch_size, shuffle=True,)
    val_loader = DataLoader(val_data, num_workers=n_workers, batch_size=batch_size, shuffle=False)
    test_loader = DataLoader(test_data, num_workers=n_workers, batch_size=batch_size, shuffle=False)

    return train_loader, val_loader, test_loader

# %% [markdown]
# ## Our Subset of MNIST

# %%
warnings.filterwarnings('ignore')
plt.rcParams['figure.figsize'] = [10, 5]
label_map = {0: 0, 1: 2, 2: 5, 3: 6, 4: 7}
def show_subset_MNIST_images(images_to_show):
    first_batch, labels = next(iter(data_loader(images_to_show)[0]))
    data_train = np.array(first_batch[:]).reshape(-1, 28, 28)
    targets = np.array(labels)
    for i in range(images_to_show):
        plt.subplot(1,images_to_show,i+1)
        plt.imshow(data_train[i], cmap='gray')
        plt.xlabel(str(label_map[targets[i]]) + " (label: " + str(targets[i]) + ")")
        plt.xticks([])
        plt.yticks([])
show_subset_MNIST_images(5)

# %% [markdown]
# ## Helper Functions

# %%
def compute_acc_loss(forward_func, data_loader):
    correct_cnt, ave_loss = 0, 0
    for batch_idx, (x, target) in enumerate(data_loader):
        with torch.no_grad():
            target = target.cuda()
            score, loss = forward_func(x.cuda(), target)
            _, pred_label = torch.max(score.data, 1)
            correct_cnt += (pred_label == target.data).sum().item()
            ave_loss += loss.data.item() * len(x)
    accuracy = correct_cnt * 1.0 / len(data_loader.dataset)
    ave_loss /= len(data_loader.dataset)
    return accuracy, ave_loss

def compute_compression_ratio(lc_alg):
    compressed_model_bits = lc_alg.count_param_bits() + (300+100+5)*32
    uncompressed_model_bits = (784*300+300*100+100*5 + 300 + 100 + 5)*32
    compression_ratio = uncompressed_model_bits/compressed_model_bits
    return compression_ratio

def train_test_acc_eval_f(net):
    train_loader, _, test_loader = data_loader()
    def forward_func(x, target):
        y = net(x)
        return y, net.loss(y, target)
    with torch.no_grad():
        acc_train, loss_train = compute_acc_loss(forward_func, train_loader)
        acc_test, loss_test = compute_acc_loss(forward_func, test_loader)

    print(f"Train err: {100-acc_train*100:.2f}%, train loss: {loss_train}")
    print(f"TEST ERR: {100-acc_test*100:.2f}%, test loss: {loss_test}")
  
def train_val_acc_eval_f(net):
    train_loader, val_loader, _ = data_loader()
    def forward_func(x, target):
        y = net(x)
        return y, net.loss(y, target)
    with torch.no_grad():
        acc_train, loss_train = compute_acc_loss(forward_func, train_loader)
        acc_val, loss_val = compute_acc_loss(forward_func, val_loader)

    return acc_train, loss_train, acc_val, loss_val

def visualize_errs(errs, subset, parameters):
    epochs = np.arange(len(errs))
    fig = plt.figure()
    ax = plt.gca()
    ax.plot(epochs * 10, errs)
    ax.set_xlabel('SGD Step')
    ax.set_title(subset + ' Accuracy per SGD step')
    ax.set_ylabel(subset + ' Accuracy')
    ax.set_xscale('log')
    ax.set_yscale('log')

def visualize_params(train_error, test_error, num_params):
    fig = plt.figure()
    ax = plt.gca()
    ax.plot(num_params, train_error)
    ax.set_xlabel('Number of Compressed Parameters')
    ax.set_title('Number of Compressed Parameters vs. Train Error')
    ax.set_ylabel('Train Error')
    ax.set_xscale('log')
    ax.set_yscale('log')
    # test
    fig1 = plt.figure()
    ax1 = plt.gca()
    ax1.plot(num_params, test_error)
    ax1.set_xlabel('Number of Compressed Parameters')
    ax1.set_title('Number of Compressed Parameters vs. Test Error')
    ax1.set_ylabel('Test Error')
    ax1.set_xscale('log')
    ax1.set_yscale('log')

def visualize_ratios(train_error, test_error, ratios):
    fig = plt.figure()
    ax = plt.gca()
    ax.plot(ratios, train_error)
    ax.set_xlabel('Compression Ratio')
    ax.set_title('Compression Ratio  vs. Train Error')
    ax.set_ylabel('Train Error')
    ax.set_xscale('linear')
    ax.set_yscale('log')
    # test
    fig1 = plt.figure()
    ax1 = plt.gca()
    ax1.plot(ratios, test_error)
    ax1.set_xlabel('Compression Ratio')
    ax1.set_title('Compression Ratio  vs. Test Error')
    ax1.set_ylabel('Test Error')
    ax1.set_xscale('linear')
    ax1.set_yscale('log')

# %% [markdown]
# ##Reference Network
# We use cuda capable GPU for our experiments. The network has 3 fully-connected layers with dimensions 784x300, 300x100, and 100x5, and the total of 266105 parameters (which includes biases).

# %%
device = torch.device('cuda')

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.loss = torch.nn.CrossEntropyLoss()
        self.fc1 = nn.Linear(784, 300)
        self.fc2 = nn.Linear(300, 100)
        self.fc3 = nn.Linear(100, 5)

    def forward(self, x):
        x = nn.functional.relu(self.fc1(x))
        x = nn.functional.relu(self.fc2(x))
        x = self.fc3(x)
        return x

def train_net(net, parameters):
    train_errs = []
    val_errs = []

    max_val_acc = 0
    #min_val_loss = np.inf
    epochs_per_early_stop_check = parameters["epochs_per_early_stop_check"]
    early_stop_thresh = 1e-5
    intitial_early_stop_patience = 3
    early_stop_patience = intitial_early_stop_patience

    train_loader, _, _ = data_loader(parameters["batch_size"])
    params = list(filter(lambda p: p.requires_grad, net.parameters()))
    optimizer = optim.SGD(params, 
                          lr=parameters["lr"], 
                          momentum=parameters["momentum"], 
                          weight_decay=parameters["weight_decay"],
                          nesterov = parameters["nesterov"])
    scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=parameters["step_size"], gamma=parameters["gamma"])
    max_epochs=100
    for epoch in range(max_epochs):
        avg_loss = []
        for i, (x, target) in enumerate(train_loader):
            optimizer.zero_grad()
            x = x.cuda()
            target = target.cuda().to(dtype=torch.long)
            out = net(x)
            loss = net.loss(out, target)
            avg_loss.append(loss.item())
            loss.backward()
            optimizer.step()
            if (i % 10 == 9):
                # -------------------------------------------------------------------------------
                acc_train, loss_train, acc_val, loss_val = train_val_acc_eval_f(net.eval())
                #print(f"\tTrain err: {100-acc_train*100:.2f}%, train loss: {loss_train}")
                #print(f"\tValidation err: {100-acc_val*100:.5f}%, validation loss: {loss_val}\n")
                train_errs.append(acc_train)
                val_errs.append(acc_val)
                # ------------------------------------------------------------------------------- 
        scheduler.step()

        print(f"\tepoch #{epoch} is finished.")
        print(f"\t  avg. train loss: {np.mean(avg_loss):.6f}")
        ## Note: when preparing final report, this chunk should be put in the inner loop
        ## to record errors for each SGD step, rather than just for each epoch (visualize
        ## errs function should also be modified accordingly)
        ## During hyperparameter tuning, it will be sufficient to find error rates only
        ## on each epoch
        # ------------------------------------------------------------------------------- 
        
        # ------------------------------------------------------------------------------- 
        #if (min_val_loss - early_stop_thresh > loss_val):
        if (epoch % epochs_per_early_stop_check == epochs_per_early_stop_check - 1):
            if (max_val_acc + early_stop_thresh < acc_val):
                #min_val_loss = loss_val
                max_val_acc = acc_val
                early_stop_patience = intitial_early_stop_patience
            else:
                early_stop_patience -= 1
            if (early_stop_patience == 0):
                break;
    
    visualize_errs(train_errs, "Train", parameters)
    visualize_errs(val_errs, "Validation", parameters)

# %% [markdown]
# ##Parameter Selection
# We use Stochastic Gradient Descent and try to find the optimal combination of momentum, batch size, learning rate, and l2 regularization.

# %%
# Batch size: powers of 2 (2^0 (batch-size 1) to 2^16 (gradient descent)) # very small batch sizes take a long time for each epoch, very large batch sizes take longer to converge
# likewise, patience too high for very small batch size
# lr: small positive number to value at which train loss oscillates up and down from very start of training (perhaps try 1e-5 - 1e4)
# gamma (factor by which learning rate decreases): small positive number to 1
# step size (how many epochs pass between each lr scheduler step): integers from 1 up
# momentum (addition of previous SGD step vector to current SGD step vector): 0 - 1 
# weight decay (penalty to loss for magnitude of weights): 0 to very large number (train error doesn't decrease because CELoss term dwarfed by weight magnitude loss term)
# nesterov (something to do with SGD, similar to momentum but looking at next update instead of previous): True or False

# Notes: 
# Wanted to find a way so that we didn't have to train every model for a long time regardless of how fast it converged, but still be able to show that validation error either increases
# or flattens out before giving up on a particular selection of hyperparameters
#   Decided to set a maximum number of epochs and use early stopping with a threshold of 1e-5 on validation accuracy to determine when to stop
#   Result is that (as long as the model didn't take longer than 100 epochs to converge) the validation accuracy curve will at least be flat for some time before stopping training
#   This introduced a new hyperparameter, epochs_per_early_stop_check, since some selections of hyperparameters will naturally take longer to converge than others
#     Training loop will only check to see if validation accuracy hasn't improved every <epochs_per_early_stop_check> epochs, allowing us to give more time to models
#     that naturally take longer to improve significantly
#     If validation accuracy hasn't improved by at least 1e-5 (.001%) since its last check, a counter is decremented. If this occurs three times, the training loop breaks
#
# Started by seeing if I could find a smaller, reasonable range of batch sizes
# for batch sizes 2^0, 2^1, 2^2 epochs each took a while and train error barely decreased, sometimes going up (lr may need to be lower in these cases)
# for batch size 2^16 (gradient descent), early stopping settings were too stringent and the model wasn't given time to converge - patience should be higher for higher batch size
# Changing learning rate to 0.01 on very small batch sizes worked very well, going to check progressively larger batch sizes to see if the learning rate is better in general
#   Lower batch sizes make epochs take longer, but the model converges to a good accuracy in fewer epochs - initial run kept going for too long after min validation error reached
#     so I reduced epochs per early stop check and trained again: validation error to beat 1.05144% (batch_size 8, lr: .01, epochs_per_early_stop_check: 3)
#   batch size 16 not doing better on val set than batch size 8 with same lr - validation accuracy flattens
#   batch sizes up to 256 weren't doing better than bs 8 with lr 0.01, so I tried increasing lr for larger batch sizes up to 0.05 and allowed model to train longer
#     models trained in this way consistently reached a minimal train and validation error and almost completely stopped moving from that point on
#     played around a bit with gamma and step size, but model error would consistently bottom out and not oscillate, so I assumed the values were good as they were
# Found that learning rates around 1 either don't work at all for smaller batch sizes, or oscillate a bit at the start then start behaving as lr_scheduler decreases it over time for larger 
#     batch sizes
# For gradient descent (batch_size 2**16), learning rate starting at about 1 works well, but a learning rate as high as 2 doesn't even work well on a very large batch size
#   Decreasing gamma helped with this, but it still underperforms compared to starting at a lower lr
# Decided to set learning rate range to be small positive number to 2. 
# 
# Best results so far have been found by setting lr relatively low and having batch size very low. In effect we are taking a very large amount of small steps towards
#   the minimizer, but I wonder if increasing the number of training epochs with a lower gamma and higher batch size may have the same effect but faster. Note: by the end of the first
#   epoch with very small batch size, the training error is typically already around 1% and validation error less than 2%
#   I have also noticed that training error will very quickly go down to 0%, and once there, the validation accuracy barely changes. 
#   I also wonder if decreasing the gamma a bit with small batch size and lr may allow us to reach a lower minimum, since I've seen the validation error reach a lower value but then
#   increase and settle at a slightly higher value later in training
# Tried decreasing gamma on lower batch size, best model is batch_size 4, lr .005, gamma .9, epochs per early stop check 2, with val accuracy of 0.94969%
# Trying to get results comparable to low batch size with a batch size of 256, by varying lr, gamma, and step size
#   While trying to do the above, we were kicked out of google colab and unable to get access to a GPU the same day
#   When we went back the next day, we were unable to get the above results with as low of validation error as we initially could, but we were able to get a model with a more
#   reasonable batch size of 128 that had validation accuracy almost as low as the other one. Since we knew that we could get kicked out of google colab again with little time
#   left to finish the project, we decided to stick with this as our final model
parameters={"batch_size": 2**8, "lr": .2, "gamma":.9, "step_size": 2, "momentum": 0.9, "weight_decay": 0, "nesterov": True, "epochs_per_early_stop_check": 3}
net = Net()

# %%
train_net(net.to(device), parameters)
# Out:
# 	epoch #0 is finished.
# 	  avg. train loss: 0.302851
# 	epoch #1 is finished.
# 	  avg. train loss: 0.039557
# 	epoch #2 is finished.
# 	  avg. train loss: 0.018912
# 	epoch #3 is finished.
# 	  avg. train loss: 0.009756
# 	epoch #4 is finished.
# 	  avg. train loss: 0.004860
# 	epoch #5 is finished.
# 	  avg. train loss: 0.002179
# 	epoch #6 is finished.
# 	  avg. train loss: 0.001063
# 	epoch #7 is finished.
# 	  avg. train loss: 0.000703
# 	epoch #8 is finished.
# 	  avg. train loss: 0.000533
# 	epoch #9 is finished.
# 	  avg. train loss: 0.000460
# 	epoch #10 is finished.
# 	  avg. train loss: 0.000398
# 	epoch #11 is finished.
# 	  avg. train loss: 0.000358
# 	epoch #12 is finished.
# 	  avg. train loss: 0.000325
# 	epoch #13 is finished.
# 	  avg. train loss: 0.000299
# 	epoch #14 is finished.
# 	  avg. train loss: 0.000276
# 	epoch #15 is finished.
# 	  avg. train loss: 0.000260
# 	epoch #16 is finished.
# 	  avg. train loss: 0.000244
# 	epoch #17 is finished.
# 	  avg. train loss: 0.000232

# %%
PATH = "/content/state_dicts/" + str(parameters) + ".pt"

# %%
torch.save(net.state_dict(), PATH)

# %%
net = Net()
net.load_state_dict(torch.load(PATH))
# Out:
# <All keys matched successfully>

# %%
parameters={"batch_size": 2**8, "lr": 0.2, "gamma":0.9, "step_size": 2, "momentum": 0.9, "weight_decay": 0, "nesterov": True}
net = Net()
net.load_state_dict(torch.load("/content/state_dicts/" + str(parameters) + ".pt"))
acc_train, loss_train, acc_val, loss_val = train_val_acc_eval_f(net.cuda().eval())
print(f"\tTrain err: {100-acc_train*100:.5f}%, train loss: {loss_train}")
print(f"\tValidation err: {100-acc_val*100:.5f}%, validation loss: {loss_val}\n")
# Out:
# 	Train err: 0.00000%, train loss: 0.0001996844643708896
# 	Validation err: 0.97230%, validation loss: 0.042836139972783405

# %%
train_test_acc_eval_f(net)
# Out:
# Train err: 0.00%, train loss: 0.00019968445818914577
# TEST ERR: 1.33%, test loss: 0.05709494277987256

# %% [markdown]
# ## Compression using the LC toolkit
# ### Step 1: L step
# We will use same L step with same hyperparamters for all our compression examples

# %%
# l_step_parameters: keep parameters 
#   learning rate: 0.7*(0.98**step), 
#   epochs per step: 7, 

# quantization parameters: codebook size (k) - powers of 2
# low rank parameters: alpha - higher alpha gives greater compression

# running each type of compression with the l-step parameters as they initially were in the demo gave good results for each compression type, so we decided to keep 
# the l-step parameters as they are and focus on seeing the impact of the mu schedule

# %%
def my_l_step(model, lc_penalty, step):
    train_loader, val_loader, test_loader = data_loader()
    params = list(filter(lambda p: p.requires_grad, model.parameters()))
    # ------------------- Learning rate parameter
    lr = 0.7*(0.98**step)
    # -------------------------------------------
    optimizer = optim.SGD(params, lr=lr, momentum=0.9, nesterov=True)
    print(f'L-step #{step} with lr: {lr:.5f}')
    epochs_per_step_ = 7
    if step == 0:
        epochs_per_step_ = epochs_per_step_ * 2
    for epoch in range(epochs_per_step_):
        avg_loss = []
        for x, target in train_loader:
            optimizer.zero_grad()
            x = x.to(device)
            target = target.to(dtype=torch.long, device=device)
            out = model(x)
            loss = model.loss(out, target) + lc_penalty()
            avg_loss.append(loss.item())
            loss.backward()
            optimizer.step()

        print(f"\tepoch #{epoch} is finished.")
        print(f"\t  avg. train loss: {np.mean(avg_loss):.6f}")

# %% [markdown]
# ### Step 2: Schedule of mu values

# %%
# mu schedule parameters: mu value should start very low and increase
#   first number is a really small number, demo had it at 9e-5
#   second number is some factor greater than 1 by which the first number should increase on each iteration, demo had it at 1.1
#   result will increase by a certain percentage (1 - second number) compounding on each step
#   third parameter is the number of step, demo had it at 20

# mu_s = [9e-5 * (1.1 ** n) for n in range(20)] test errors: pruning: 1.23%, quantization: 2.37%, low-rank: 1.33%

# First thing I would try is to increase the number of steps, to see if iterating longer leads to better results
#   This will come at the cost of extra computation time, so if the effect is small, we should keep it as it is
#   Looking at the initial run with default mu schedule, it looks like the quanization error was actually lower for earlier 
#   iteration, and happened to be a bit higher for the final iteration (test accuracy, not train accuracy)
#   Maybe try fewer iterations first, see if result is similar to first run and save some time by using fewer iterations
#
#     mu_s = [9e-5 * (1.1 ** n) for n in range(17)] test errors: pruning: 1.45%, quantization: 1.45%, low-rank: 1.43%
#         Error on quantization was lower by nearly a percent, slightly higher on pruning and low rank
#         I'm going to see if we can get lower error on quantization by letting it go for a few more iterations in order to keep the better error rates on the other two

#     mu_s = [9e-5 * (1.1 ** n) for n in range(23)] test errors: pruning: 1.21%, quantization: 1.31%, low-rank: 1.41%
#         This is an improvement on pruning and quantization

#     We decided to select a range of values that seemed reasonable for each parameter, then go through them one by one (keeping the values of the other parameters fixed)
#       and compress with each compression type to compare error rates for each value. We then select the best value out of those that we tried and repeat with the next 
#       parameter. Once we have the best values for the first two parameters, we will set those and see if increasing the number of iterations improves test error.
#     9e-3, 9e-5, 9e-6, 9e-7
#     mu_s = [9e-5 * (1.1 ** n) for n in range(17)] test errors: pruning: 1.45%, quantization: 1.45%, low-rank: 1.43%
#     mu_s = [9e-6 * (1.1  n) for n in range(20)] test errors: pruning: 3.05% , quantization: 5.69%, low-rank: 72.80%
#     mu_s = [9e-7 * (1.1 ** n) for n in range(20)] test errors: pruning: 4.17%, quantization: 5.89%, low-rank: 78.90%
#     mu_s = [9e-7 * (1.1 ** n) for n in range(20)] test errors: pruning: 4.17%, quantization: 5.89%, low-rank: 78.90%

#     1.01, 1.05, 1.1, 1.2
#     mu_s = [9e-5 * (1.05 ** n) for n in range(20)] test errors: pruning: 1.47%, quantization: 1.47%, low-rank: 5.85%
#     mu_s = [9e-5 * (1.1 ** n) for n in range(20)] test errors: pruning: 1.23%, quantization: 2.37%, low-rank: 1.33%
#     mu_s = [9e-5 * (1.2 ** n) for n in range(20)] test errors: pruning: 2.97%, quantization: 10.33%, low-rank: 79.96%

#     Number of iteration:
#       17, 20, 23, 25, 30
#     mu_s = [9e-5 * (1.1 ** n) for n in range(17)] test errors: pruning: 1.45%, quantization: 1.45%, low-rank: 1.43%
#     mu_s = [9e-5 * (1.1 ** n) for n in range(20)] test errors: pruning: 1.23%, quantization: 2.37%, low-rank: 1.33%
#     mu_s = [9e-5 * (1.1 ** n) for n in range(23)] test errors: pruning: 1.21%, quantization: 1.31%, low-rank: 1.41%
#     mu_s = [9e-5 * (1.1  n) for n in range(25)] test errors: pruning: 1.17%, quantization: 1.62%, low-rank: 1.41%
#     mu_s = [9e-5 * (1.1 ** n) for n in range(30)]
#     mu_s = [9e-5 * (1.1 ** n) for n in range(35)]
#     mu_s = [9e-5 * (1.1 ** n) for n in range(40)] test errors: pruning: 1.19%, quantization: 1.43%, low-rank: 1.37%

mu_s = [9e-5 * (1.1 ** n) for n in range(23)] # 0 to infinity
# 20 L-C steps in total
# total training epochs is 7 x 20 = 140

# %% [markdown]
# ### Compression time! Pruning
# Let us prune all but 5% of the weights in the network (5% = 13310 weights)

# %%
# pruning parameter: kappa - controls how many weights will be in the compressed model (excluding biases)

# %%
parameters={'batch_size': 256, 'lr': 0.2, 'gamma': 0.9, 'step_size': 2, 'momentum': 0.9, 'weight_decay': 0, 'nesterov': True}
net = Net().cuda()
net.load_state_dict(torch.load("/content/state_dicts/" + str(parameters) + ".pt"))


layers = [lambda x=x: getattr(x, 'weight') for x in net.modules() if isinstance(x, nn.Linear)]
compression_tasks = {
    Param(layers, device): (AsVector, ConstraintL0Pruning(
            kappa=13285
          ), 'pruning')
}

lc_alg = lc.Algorithm(
    model=net,                            # model to compress
    compression_tasks=compression_tasks,  # specifications of compression
    l_step_optimization=my_l_step,        # implementation of L-step
    mu_schedule=mu_s,                     # schedule of mu values
    evaluation_func=train_test_acc_eval_f # evaluation function
)
lc_alg.run()                              # entry point to the LC algorithm
print('Compressed_params:', lc_alg.count_params())
print('Compression_ratio:', compute_compression_ratio(lc_alg))
# Out:
# from retrieve 276.9761156987101
# L0 constrained pruning.
# l0-cons pruning finished. #zeros: 95.00%
# Direct compression has been performed.
# Train err: 2.53%, train loss: 0.07811216245325961
# TEST ERR: 3.39%, test loss: 0.10174675736507754
# 9e-05
# L-step #0 with lr: 0.70000
# 	epoch #0 is finished.
# 	  avg. train loss: 0.007264
# 	epoch #1 is finished.
# 	  avg. train loss: 0.007199
# 	epoch #2 is finished.
# 	  avg. train loss: 0.007118
# 	epoch #3 is finished.
# 	  avg. train loss: 0.007020
# 	epoch #4 is finished.
# 	  avg. train loss: 0.006924
# 	epoch #5 is finished.
# 	  avg. train loss: 0.006856
# 	epoch #6 is finished.
# 	  avg. train loss: 0.006768
# 	epoch #7 is finished.
# 	  avg. train loss: 0.006682
# 	epoch #8 is finished.
# 	  avg. train loss: 0.006585
# 	epoch #9 is finished.
# 	  avg. train loss: 0.006500
# 	epoch #10 is finished.
# 	  avg. train loss: 0.006411
# 	epoch #11 is finished.
# 	  avg. train loss: 0.006338
# 	epoch #12 is finished.
# 	  avg. train loss: 0.006245
# 	epoch #13 is finished.
# 	  avg. train loss: 0.006187
# from retrieve 256.77939024267533
# L-step #0 has finished.
# L0 constrained pruning.
# l0-cons pruning finished. #zeros: 95.00%
# C-step #0 has finished.
# Lagrange multipliers have been updated.
# Train err: 2.43%, train loss: 0.07269911719269531
# TEST ERR: 3.25%, test loss: 0.09870855902114041
# 9.45e-05
# L-step #1 with lr: 0.68600
# 	epoch #0 is finished.
# 	  avg. train loss: 0.023945
# 	epoch #1 is finished.
# 	  avg. train loss: 0.023730
# 	epoch #2 is finished.
# 	  avg. train loss: 0.023428
# 	epoch #3 is finished.
# 	  avg. train loss: 0.023136
# 	epoch #4 is finished.
# 	  avg. train loss: 0.022831
# 	epoch #5 is finished.
# 	  avg. train loss: 0.022526
# 	epoch #6 is finished.
# 	  avg. train loss: 0.022228
# from retrieve 237.99424328171915
# L-step #1 has finished.
# L0 constrained pruning.
# l0-cons pruning finished. #zeros: 95.00%
# C-step #1 has finished.
# Lagrange multipliers have been updated.
# Train err: 2.41%, train loss: 0.08499959866667903
# TEST ERR: 3.74%, test loss: 0.1127616527347477
# 9.922500000000001e-05
# L-step #2 with lr: 0.67228
# 	epoch #0 is finished.
# 	  avg. train loss: 0.049257
# 	epoch #1 is finished.
# 	  avg. train loss: 0.048811
# 	epoch #2 is finished.
# 	  avg. train loss: 0.048195
# 	epoch #3 is finished.
# 	  avg. train loss: 0.047559
# 	epoch #4 is finished.
# 	  avg. train loss: 0.046889
# 	epoch #5 is finished.
# 	  avg. train loss: 0.046235
# 	epoch #6 is finished.
# 	  avg. train loss: 0.045608
# from retrieve 212.81487834593207
# L-step #2 has finished.
# L0 constrained pruning.
# l0-cons pruning finished. #zeros: 95.00%
# C-step #2 has finished.
# Lagrange multipliers have been updated.
# Train err: 0.84%, train loss: 0.028628800569694173
# TEST ERR: 2.17%, test loss: 0.07148713675196186
# 0.00010418625000000001
# L-step #3 with lr: 0.65883
# 	epoch #0 is finished.
# 	  avg. train loss: 0.069852
# 	epoch #1 is finished.
# 	  avg. train loss: 0.069164
# 	epoch #2 is finished.
# 	  avg. train loss: 0.068278
# 	epoch #3 is finished.
# 	  avg. train loss: 0.067318
# 	epoch #4 is finished.
# 	  avg. train loss: 0.066368
# 	epoch #5 is finished.
# 	  avg. train loss: 0.065418
# 	epoch #6 is finished.
# 	  avg. train loss: 0.064493
# from retrieve 190.90997370407476
# L-step #3 has finished.
# L0 constrained pruning.
# l0-cons pruning finished. #zeros: 95.00%
# C-step #3 has finished.
# Lagrange multipliers have been updated.
# Train err: 1.83%, train loss: 0.052000638715518535
# TEST ERR: 2.76%, test loss: 0.09189967567325857
# 0.00010939556250000002
# L-step #4 with lr: 0.64566
# 	epoch #0 is finished.
# 	  avg. train loss: 0.088465
# 	epoch #1 is finished.
# 	  avg. train loss: 0.087581
# 	epoch #2 is finished.
# 	  avg. train loss: 0.086417
# 	epoch #3 is finished.
# 	  avg. train loss: 0.085191
# 	epoch #4 is finished.
# 	  avg. train loss: 0.083947
# 	epoch #5 is finished.
# 	  avg. train loss: 0.082721
# 	epoch #6 is finished.
# 	  avg. train loss: 0.081530
# from retrieve 170.30599744521652
# L-step #4 has finished.
# L0 constrained pruning.
# l0-cons pruning finished. #zeros: 95.00%
# C-step #4 has finished.
# Lagrange multipliers have been updated.
# Train err: 1.00%, train loss: 0.030432990684296734
# TEST ERR: 2.64%, test loss: 0.0849743473231183
# 0.00011486534062500004
# L-step #5 with lr: 0.63274
# 	epoch #0 is finished.
# 	  avg. train loss: 0.097955
# 	epoch #1 is finished.
# 	  avg. train loss: 0.096914
# 	epoch #2 is finished.
# 	  avg. train loss: 0.095605
# 	epoch #3 is finished.
# 	  avg. train loss: 0.094244
# 	epoch #4 is finished.
# 	  avg. train loss: 0.092839
# 	epoch #5 is finished.
# 	  avg. train loss: 0.091459
# 	epoch #6 is finished.
# 	  avg. train loss: 0.090118
# from retrieve 155.16244446891082
# L-step #5 has finished.
# L0 constrained pruning.
# l0-cons pruning finished. #zeros: 95.00%
# C-step #5 has finished.
# Lagrange multipliers have been updated.
# Train err: 1.52%, train loss: 0.04495201473550279
# TEST ERR: 2.56%, test loss: 0.09675157349594775
# 0.00012060860765625005
# L-step #6 with lr: 0.62009
# 	epoch #0 is finished.
# 	  avg. train loss: 0.095583
# 	epoch #1 is finished.
# 	  avg. train loss: 0.094613
# 	epoch #2 is finished.
# 	  avg. train loss: 0.093304
# 	epoch #3 is finished.
# 	  avg. train loss: 0.091917
# 	epoch #4 is finished.
# 	  avg. train loss: 0.090504
# 	epoch #5 is finished.
# 	  avg. train loss: 0.089156
# 	epoch #6 is finished.
# 	  avg. train loss: 0.087765
# from retrieve 151.82141397316195
# L-step #6 has finished.
# L0 constrained pruning.
# l0-cons pruning finished. #zeros: 95.00%
# C-step #6 has finished.
# Lagrange multipliers have been updated.
# Train err: 1.50%, train loss: 0.04088162281369978
# TEST ERR: 2.88%, test loss: 0.09779611185406371
# 0.00012663903803906255
# L-step #7 with lr: 0.60769
# 	epoch #0 is finished.
# 	  avg. train loss: 0.091817
# 	epoch #1 is finished.
# 	  avg. train loss: 0.090806
# 	epoch #2 is finished.
# 	  avg. train loss: 0.089538
# 	epoch #3 is finished.
# 	  avg. train loss: 0.088182
# 	epoch #4 is finished.
# 	  avg. train loss: 0.086812
# 	epoch #5 is finished.
# 	  avg. train loss: 0.085509
# 	epoch #6 is finished.
# 	  avg. train loss: 0.084166
# from retrieve 148.38534076747644
# L-step #7 has finished.
# L0 constrained pruning.
# l0-cons pruning finished. #zeros: 95.00%
# C-step #7 has finished.
# Lagrange multipliers have been updated.
# Train err: 0.61%, train loss: 0.015370354160319927
# TEST ERR: 1.57%, test loss: 0.07001354827227524
# 0.00013297098994101569
# L-step #8 with lr: 0.59553
# 	epoch #0 is finished.
# 	  avg. train loss: 0.080540
# 	epoch #1 is finished.
# 	  avg. train loss: 0.079692
# 	epoch #2 is finished.
# 	  avg. train loss: 0.078455
# 	epoch #3 is finished.
# 	  avg. train loss: 0.077302
# 	epoch #4 is finished.
# 	  avg. train loss: 0.076047
# 	epoch #5 is finished.
# 	  avg. train loss: 0.074790
# 	epoch #6 is finished.
# 	  avg. train loss: 0.073563
# from retrieve 151.68225135668467
# L-step #8 has finished.
# L0 constrained pruning.
# l0-cons pruning finished. #zeros: 95.00%
# C-step #8 has finished.
# Lagrange multipliers have been updated.
# Train err: 0.45%, train loss: 0.014756534153653323
# TEST ERR: 1.82%, test loss: 0.06462406047099939
# 0.00013961953943806646
# L-step #9 with lr: 0.58362
# 	epoch #0 is finished.
# 	  avg. train loss: 0.064741
# 	epoch #1 is finished.
# 	  avg. train loss: 0.064047
# 	epoch #2 is finished.
# 	  avg. train loss: 0.063089
# 	epoch #3 is finished.
# 	  avg. train loss: 0.062142
# 	epoch #4 is finished.
# 	  avg. train loss: 0.061129
# 	epoch #5 is finished.
# 	  avg. train loss: 0.060154
# 	epoch #6 is finished.
# 	  avg. train loss: 0.059174
# from retrieve 159.34612451122356
# L-step #9 has finished.
# L0 constrained pruning.
# l0-cons pruning finished. #zeros: 95.00%
# C-step #9 has finished.
# Lagrange multipliers have been updated.
# Train err: 1.11%, train loss: 0.02973473194495652
# TEST ERR: 2.29%, test loss: 0.08995260011503789
# 0.00014660051640996978
# L-step #10 with lr: 0.57195
# 	epoch #0 is finished.
# 	  avg. train loss: 0.051386
# 	epoch #1 is finished.
# 	  avg. train loss: 0.050811
# 	epoch #2 is finished.
# 	  avg. train loss: 0.050063
# 	epoch #3 is finished.
# 	  avg. train loss: 0.049259
# 	epoch #4 is finished.
# 	  avg. train loss: 0.048471
# 	epoch #5 is finished.
# 	  avg. train loss: 0.047751
# 	epoch #6 is finished.
# 	  avg. train loss: 0.047012
# from retrieve 166.71133210207125
# L-step #10 has finished.
# L0 constrained pruning.
# l0-cons pruning finished. #zeros: 95.00%
# C-step #10 has finished.
# Lagrange multipliers have been updated.
# Train err: 0.31%, train loss: 0.008857588120555693
# TEST ERR: 1.96%, test loss: 0.07470486868012902
# 0.0001539305422304683
# L-step #11 with lr: 0.56051
# 	epoch #0 is finished.
# 	  avg. train loss: 0.036580
# 	epoch #1 is finished.
# 	  avg. train loss: 0.036141
# 	epoch #2 is finished.
# 	  avg. train loss: 0.035541
# 	epoch #3 is finished.
# 	  avg. train loss: 0.034987
# 	epoch #4 is finished.
# 	  avg. train loss: 0.034404
# 	epoch #5 is finished.
# 	  avg. train loss: 0.033849
# 	epoch #6 is finished.
# 	  avg. train loss: 0.033308
# from retrieve 174.62522902910564
# L-step #11 has finished.
# L0 constrained pruning.
# l0-cons pruning finished. #zeros: 95.00%
# C-step #11 has finished.
# Lagrange multipliers have been updated.
# Train err: 0.87%, train loss: 0.023812267085349607
# TEST ERR: 2.00%, test loss: 0.07821167533443993
# 0.00016162706934199172
# L-step #12 with lr: 0.54930
# 	epoch #0 is finished.
# 	  avg. train loss: 0.028650
# 	epoch #1 is finished.
# 	  avg. train loss: 0.028310
# 	epoch #2 is finished.
# 	  avg. train loss: 0.027927
# 	epoch #3 is finished.
# 	  avg. train loss: 0.027484
# 	epoch #4 is finished.
# 	  avg. train loss: 0.027105
# 	epoch #5 is finished.
# 	  avg. train loss: 0.026645
# 	epoch #6 is finished.
# 	  avg. train loss: 0.026224
# from retrieve 179.4767799772197
# L-step #12 has finished.
# L0 constrained pruning.
# l0-cons pruning finished. #zeros: 95.00%
# C-step #12 has finished.
# Lagrange multipliers have been updated.
# Train err: 0.05%, train loss: 0.003041870440284238
# TEST ERR: 1.45%, test loss: 0.06474257431208234
# 0.0001697084228090913
# L-step #13 with lr: 0.53832
# 	epoch #0 is finished.
# 	  avg. train loss: 0.021007
# 	epoch #1 is finished.
# 	  avg. train loss: 0.020781
# 	epoch #2 is finished.
# 	  avg. train loss: 0.020492
# 	epoch #3 is finished.
# 	  avg. train loss: 0.020139
# 	epoch #4 is finished.
# 	  avg. train loss: 0.019778
# 	epoch #5 is finished.
# 	  avg. train loss: 0.019440
# 	epoch #6 is finished.
# 	  avg. train loss: 0.019115
# from retrieve 183.2433255027842
# L-step #13 has finished.
# L0 constrained pruning.
# l0-cons pruning finished. #zeros: 95.00%
# C-step #13 has finished.
# Lagrange multipliers have been updated.
# Train err: 0.37%, train loss: 0.010333685805053673
# TEST ERR: 1.74%, test loss: 0.0628075878495819
# 0.0001781938439495459
# L-step #14 with lr: 0.52755
# 	epoch #0 is finished.
# 	  avg. train loss: 0.024997
# 	epoch #1 is finished.
# 	  avg. train loss: 0.024712
# 	epoch #2 is finished.
# 	  avg. train loss: 0.024374
# 	epoch #3 is finished.
# 	  avg. train loss: 0.023978
# 	epoch #4 is finished.
# 	  avg. train loss: 0.023540
# 	epoch #5 is finished.
# 	  avg. train loss: 0.023136
# 	epoch #6 is finished.
# 	  avg. train loss: 0.022743
# from retrieve 181.32357028945586
# L-step #14 has finished.
# L0 constrained pruning.
# l0-cons pruning finished. #zeros: 95.00%
# C-step #14 has finished.
# Lagrange multipliers have been updated.
# Train err: 0.18%, train loss: 0.005414007553946255
# TEST ERR: 1.45%, test loss: 0.06764901004625
# 0.0001871035361470232
# L-step #15 with lr: 0.51700
# 	epoch #0 is finished.
# 	  avg. train loss: 0.025887
# 	epoch #1 is finished.
# 	  avg. train loss: 0.025530
# 	epoch #2 is finished.
# 	  avg. train loss: 0.025111
# 	epoch #3 is finished.
# 	  avg. train loss: 0.024660
# 	epoch #4 is finished.
# 	  avg. train loss: 0.024224
# 	epoch #5 is finished.
# 	  avg. train loss: 0.023769
# 	epoch #6 is finished.
# 	  avg. train loss: 0.023365
# from retrieve 180.64784416194274
# L-step #15 has finished.
# L0 constrained pruning.
# l0-cons pruning finished. #zeros: 95.00%
# C-step #15 has finished.
# Lagrange multipliers have been updated.
# Train err: 0.08%, train loss: 0.003408218183114316
# TEST ERR: 1.53%, test loss: 0.0664336441271388
# 0.00019645871295437433
# L-step #16 with lr: 0.50666
# 	epoch #0 is finished.
# 	  avg. train loss: 0.031885
# 	epoch #1 is finished.
# 	  avg. train loss: 0.031471
# 	epoch #2 is finished.
# 	  avg. train loss: 0.030926
# 	epoch #3 is finished.
# 	  avg. train loss: 0.030303
# 	epoch #4 is finished.
# 	  avg. train loss: 0.029708
# 	epoch #5 is finished.
# 	  avg. train loss: 0.029138
# 	epoch #6 is finished.
# 	  avg. train loss: 0.028564
# from retrieve 176.75335256396085
# L-step #16 has finished.
# L0 constrained pruning.
# l0-cons pruning finished. #zeros: 95.00%
# C-step #16 has finished.
# Lagrange multipliers have been updated.
# Train err: 0.04%, train loss: 0.0024753802424376152
# TEST ERR: 1.70%, test loss: 0.06853268382373763
# 0.00020628164860209307
# L-step #17 with lr: 0.49653
# 	epoch #0 is finished.
# 	  avg. train loss: 0.033743
# 	epoch #1 is finished.
# 	  avg. train loss: 0.033235
# 	epoch #2 is finished.
# 	  avg. train loss: 0.032610
# 	epoch #3 is finished.
# 	  avg. train loss: 0.031938
# 	epoch #4 is finished.
# 	  avg. train loss: 0.031298
# 	epoch #5 is finished.
# 	  avg. train loss: 0.030653
# 	epoch #6 is finished.
# 	  avg. train loss: 0.030020
# from retrieve 175.57160928307673
# L-step #17 has finished.
# L0 constrained pruning.
# l0-cons pruning finished. #zeros: 95.00%
# C-step #17 has finished.
# Lagrange multipliers have been updated.
# Train err: 0.10%, train loss: 0.00427018792491204
# TEST ERR: 1.43%, test loss: 0.05639754667847678
# 0.00021659573103219773
# L-step #18 with lr: 0.48659
# 	epoch #0 is finished.
# 	  avg. train loss: 0.036809
# 	epoch #1 is finished.
# 	  avg. train loss: 0.036256
# 	epoch #2 is finished.
# 	  avg. train loss: 0.035555
# 	epoch #3 is finished.
# 	  avg. train loss: 0.034805
# 	epoch #4 is finished.
# 	  avg. train loss: 0.034071
# 	epoch #5 is finished.
# 	  avg. train loss: 0.033374
# 	epoch #6 is finished.
# 	  avg. train loss: 0.032661
# from retrieve 173.62585982779106
# L-step #18 has finished.
# L0 constrained pruning.
# l0-cons pruning finished. #zeros: 95.00%
# C-step #18 has finished.
# Lagrange multipliers have been updated.
# Train err: 0.01%, train loss: 0.0014363114657097084
# TEST ERR: 1.21%, test loss: 0.06047227889421283
# 0.00022742551758380764
# L-step #19 with lr: 0.47686
# 	epoch #0 is finished.
# 	  avg. train loss: 0.033506
# 	epoch #1 is finished.
# 	  avg. train loss: 0.032988
# 	epoch #2 is finished.
# 	  avg. train loss: 0.032321
# 	epoch #3 is finished.
# 	  avg. train loss: 0.031598
# 	epoch #4 is finished.
# 	  avg. train loss: 0.030894
# 	epoch #5 is finished.
# 	  avg. train loss: 0.030259
# 	epoch #6 is finished.
# 	  avg. train loss: 0.029572
# from retrieve 175.31724559541544
# L-step #19 has finished.
# L0 constrained pruning.
# l0-cons pruning finished. #zeros: 95.00%
# C-step #19 has finished.
# Lagrange multipliers have been updated.
# Train err: 0.03%, train loss: 0.0019878732892431956
# TEST ERR: 1.47%, test loss: 0.06254940404421469
# Compressed_params: 13285
# Compression_ratio: 16.068405687917885

# %% [markdown]
# ### Quantization
# Now let us quantize each layer with its own codebook

# %%
parameters={'batch_size': 256, 'lr': 0.2, 'gamma': 0.9, 'step_size': 2, 'momentum': 0.9, 'weight_decay': 0, 'nesterov': True}
net = Net().cuda()
net.load_state_dict(torch.load("/content/state_dicts/" + str(parameters) + ".pt"))

layers = [lambda x=x: getattr(x, 'weight') for x in net.modules() if isinstance(x, nn.Linear)]
# k = 2 for each layer gives 30x compression
# k = 4 for each layer gives 15x compression
# k = 8 for each layer gives 10x compression
# k = 16 for each layer gives about 8x compression
# k = 32 for each layer gives about 6.2x compression
# k = 64 for each layer gives about 5.28x compresssion
# k = 128 for each layer gives about 4.5x compression

compression_tasks = {
    Param(layers[0], device): (AsVector, AdaptiveQuantization(k=2), 'layer0_quant'),
    Param(layers[1], device): (AsVector, AdaptiveQuantization(k=2), 'layer1_quant'),
    Param(layers[2], device): (AsVector, AdaptiveQuantization(k=2), 'layer2_quant')
}

lc_alg = lc.Algorithm(
    model=net,                            # model to compress
    compression_tasks=compression_tasks,  # specifications of compression
    l_step_optimization=my_l_step,        # implementation of L-step
    mu_schedule=mu_s,                     # schedule of mu values
    evaluation_func=train_test_acc_eval_f # evaluation function
)
lc_alg.run()  
print('Compressed_params:', lc_alg.count_params())
print('Compression_ratio:', compute_compression_ratio(lc_alg))
# Out:
# from retrieve 174.84155325678307
# from retrieve 69.29116793712554
# from retrieve 32.8433945048008
# None k-means++
# K-Means converged in 19 iterations.
# None k-means++
# K-Means converged in 19 iterations.
# None k-means++
# K-Means converged in 13 iterations.
# Direct compression has been performed.
# Train err: 5.88%, train loss: 0.2785877668580344
# TEST ERR: 5.95%, test loss: 0.28041729967896434
# 9e-05
# L-step #0 with lr: 0.70000
# 	epoch #0 is finished.
# 	  avg. train loss: 0.004735
# 	epoch #1 is finished.
# 	  avg. train loss: 0.004707
# 	epoch #2 is finished.
# 	  avg. train loss: 0.004664
# 	epoch #3 is finished.
# 	  avg. train loss: 0.004615
# 	epoch #4 is finished.
# 	  avg. train loss: 0.004567
# 	epoch #5 is finished.
# 	  avg. train loss: 0.004518
# 	epoch #6 is finished.
# 	  avg. train loss: 0.004482
# 	epoch #7 is finished.
# 	  avg. train loss: 0.004438
# 	epoch #8 is finished.
# 	  avg. train loss: 0.004382
# 	epoch #9 is finished.
# 	  avg. train loss: 0.004346
# 	epoch #10 is finished.
# 	  avg. train loss: 0.004291
# 	epoch #11 is finished.
# 	  avg. train loss: 0.004243
# 	epoch #12 is finished.
# 	  avg. train loss: 0.004198
# 	epoch #13 is finished.
# 	  avg. train loss: 0.004159
# from retrieve 166.58843824569382
# from retrieve 67.41502551252115
# from retrieve 32.74333314580918
# L-step #0 has finished.
# {'cluster_centers': array([[ 0.0215216 ],
#        [-0.02222148]]), 'assignments': array([ 50,  45,  46, ..., 140, 183,  54], dtype=uint8), 'data_shape': (235200,)} [[ 0.0215216 ]
#  [-0.02222148]]
# K-Means converged in 2 iterations.
# {'cluster_centers': array([[ 0.04733047],
#        [-0.02872253]]), 'assignments': array([ 70,  68, 234, ..., 232, 212,  54], dtype=uint8), 'data_shape': (30000,)} [[ 0.04733047]
#  [-0.02872253]]
# K-Means converged in 2 iterations.
# {'cluster_centers': array([[-0.11779187],
#        [ 0.31172782]]), 'assignments': array([ 40,  10,   1, 250, 192,  17,   1,  24, 144,  24,   8,  83, 129,
#         19,  16,   8,  35,  85,  20,   4,  68, 172,  32,  84,  14,  64,
#         32, 168,  53,   5, 140, 167,  81,   0,  65, 195,  66, 194,   5,
#        192, 145,  72, 132,  45, 162, 152,   4, 218,   0,  16, 203, 130,
#         36, 160,   0, 120,   9,   0,   8,   0,  20,   6,   0], dtype=uint8), 'data_shape': (500,)} [[-0.11779187]
#  [ 0.31172782]]
# K-Means converged in 2 iterations.
# C-step #0 has finished.
# Lagrange multipliers have been updated.
# Train err: 5.61%, train loss: 0.2591478351012681
# TEST ERR: 5.83%, test loss: 0.262758495081178
# 9.45e-05
# L-step #1 with lr: 0.68600
# 	epoch #0 is finished.
# 	  avg. train loss: 0.015883
# 	epoch #1 is finished.
# 	  avg. train loss: 0.015767
# 	epoch #2 is finished.
# 	  avg. train loss: 0.015598
# 	epoch #3 is finished.
# 	  avg. train loss: 0.015426
# 	epoch #4 is finished.
# 	  avg. train loss: 0.015239
# 	epoch #5 is finished.
# 	  avg. train loss: 0.015093
# 	epoch #6 is finished.
# 	  avg. train loss: 0.014922
# from retrieve 159.19571846062877
# from retrieve 65.19781469019469
# from retrieve 31.96753833195076
# L-step #1 has finished.
# {'cluster_centers': array([[ 0.02161067],
#        [-0.0223412 ]]), 'assignments': array([ 50,  45,  46, ..., 140, 183,  54], dtype=uint8), 'data_shape': (235200,)} [[ 0.02161067]
#  [-0.0223412 ]]
# K-Means converged in 16 iterations.
# {'cluster_centers': array([[ 0.04805802],
#        [-0.02900038]]), 'assignments': array([ 70,  68, 234, ..., 232, 212,  54], dtype=uint8), 'data_shape': (30000,)} [[ 0.04805802]
#  [-0.02900038]]
# K-Means converged in 26 iterations.
# {'cluster_centers': array([[-0.12220945],
#        [ 0.3230842 ]]), 'assignments': array([ 40,  10,   1, 250, 192,  17,   1,  24, 144,  24,   8,  83, 129,
#         19,  16,   8,  35,  85,  20,   4,  68, 172,  32,  84,  14,  64,
#         32, 168,  53,   5, 140, 167,  81,   0,  65, 195,  66, 194,   5,
#        192, 145,  72, 132,  45, 162, 152,   4, 218,   0,  16, 203, 130,
#         36, 160,   0, 120,   9,   0,   8,   0,  20,   6,   0], dtype=uint8), 'data_shape': (500,)} [[-0.12220945]
#  [ 0.3230842 ]]
# K-Means converged in 21 iterations.
# C-step #1 has finished.
# Lagrange multipliers have been updated.
# Train err: 6.98%, train loss: 0.23913278136142466
# TEST ERR: 8.16%, test loss: 0.2578823251714492
# 9.922500000000001e-05
# L-step #2 with lr: 0.67228
# 	epoch #0 is finished.
# 	  avg. train loss: 0.032747
# 	epoch #1 is finished.
# 	  avg. train loss: 0.032456
# 	epoch #2 is finished.
# 	  avg. train loss: 0.032100
# 	epoch #3 is finished.
# 	  avg. train loss: 0.031710
# 	epoch #4 is finished.
# 	  avg. train loss: 0.031353
# 	epoch #5 is finished.
# 	  avg. train loss: 0.030976
# 	epoch #6 is finished.
# 	  avg. train loss: 0.030573
# from retrieve 149.46977457127448
# from retrieve 62.261770559240915
# from retrieve 31.203080244194716
# L-step #2 has finished.
# {'cluster_centers': array([[ 0.02524288],
#        [-0.02613272]]), 'assignments': array([163,   3, 184, ..., 142, 246,  52], dtype=uint8), 'data_shape': (235200,)} [[ 0.02524288]
#  [-0.02613272]]
# K-Means converged in 12 iterations.
# {'cluster_centers': array([[ 0.0570887 ],
#        [-0.03418063]]), 'assignments': array([ 71,  17, 162, ..., 113, 215,  38], dtype=uint8), 'data_shape': (30000,)} [[ 0.0570887 ]
#  [-0.03418063]]
# K-Means converged in 11 iterations.
# {'cluster_centers': array([[-0.4400885 ],
#        [ 0.15796666]]), 'assignments': array([ 62, 218, 243, 255, 254,  81,   5, 251, 255,  63, 107, 251, 241,
#         95,  93, 237, 191, 255, 247, 236, 247, 255, 101, 254, 175, 252,
#        233, 254,  61,  55, 174, 231, 255,  55, 237, 255, 254, 210, 237,
#        247, 245, 238, 244, 109, 238, 187, 215, 251,  11, 159, 255, 210,
#        255, 236, 254, 124, 191, 190, 191, 182, 246, 174,  16], dtype=uint8), 'data_shape': (500,)} [[-0.4400885 ]
#  [ 0.15796666]]
# K-Means converged in 9 iterations.
# C-step #2 has finished.
# Lagrange multipliers have been updated.
# Train err: 3.23%, train loss: 0.08496888653599015
# TEST ERR: 4.48%, test loss: 0.136526561027168
# 0.00010418625000000001
# L-step #3 with lr: 0.65883
# 	epoch #0 is finished.
# 	  avg. train loss: 0.042843
# 	epoch #1 is finished.
# 	  avg. train loss: 0.042444
# 	epoch #2 is finished.
# 	  avg. train loss: 0.041936
# 	epoch #3 is finished.
# 	  avg. train loss: 0.041408
# 	epoch #4 is finished.
# 	  avg. train loss: 0.040909
# 	epoch #5 is finished.
# 	  avg. train loss: 0.040378
# 	epoch #6 is finished.
# 	  avg. train loss: 0.039866
# from retrieve 141.91137482400924
# from retrieve 60.37036865398959
# from retrieve 31.96094708381073
# L-step #3 has finished.
# {'cluster_centers': array([[ 0.03050585],
#        [-0.0311831 ]]), 'assignments': array([ 50, 237,  46, ..., 140, 149,  54], dtype=uint8), 'data_shape': (235200,)} [[ 0.03050585]
#  [-0.0311831 ]]
# K-Means converged in 41 iterations.
# {'cluster_centers': array([[ 0.06508351],
#        [-0.0455472 ]]), 'assignments': array([ 70,  68, 234, ..., 238, 208, 187], dtype=uint8), 'data_shape': (30000,)} [[ 0.06508351]
#  [-0.0455472 ]]
# K-Means converged in 19 iterations.
# {'cluster_centers': array([[-0.14389269],
#        [ 0.79434149]]), 'assignments': array([  0,  10,   0,  64,  64,  17,   1,   0,   0,  24,   8,  19, 129,
#         18,  16,   8,   2,   1,  20,   4,  68, 172,   0,  80,   2,  64,
#          0,  32,  37,   1, 132, 162,  80,   0,  64, 192,  64,  66,   0,
#        192, 129,   0, 128,  37,   2,   8,   0, 154,   0,  16, 203,   0,
#          0,  32,   0,  32,   8,   0,   0,   0,  20,   4,   0], dtype=uint8), 'data_shape': (500,)} [[-0.14389269]
#  [ 0.79434149]]
# K-Means converged in 22 iterations.
# C-step #3 has finished.
# Lagrange multipliers have been updated.
# Train err: 6.24%, train loss: 0.1663408846356148
# TEST ERR: 6.40%, test loss: 0.20164879759762186
# 0.00010939556250000002
# L-step #4 with lr: 0.64566
# 	epoch #0 is finished.
# 	  avg. train loss: 0.052687
# 	epoch #1 is finished.
# 	  avg. train loss: 0.052189
# 	epoch #2 is finished.
# 	  avg. train loss: 0.051623
# 	epoch #3 is finished.
# 	  avg. train loss: 0.050953
# 	epoch #4 is finished.
# 	  avg. train loss: 0.050282
# 	epoch #5 is finished.
# 	  avg. train loss: 0.049681
# 	epoch #6 is finished.
# 	  avg. train loss: 0.049031
# from retrieve 134.15143340922765
# from retrieve 58.5883104310836
# from retrieve 32.11565527004725
# L-step #4 has finished.
# {'cluster_centers': array([[ 0.01799376],
#        [-0.05137237]]), 'assignments': array([ 32,   1,   8, ..., 132, 178,  52], dtype=uint8), 'data_shape': (235200,)} [[ 0.01799376]
#  [-0.05137237]]
# K-Means converged in 15 iterations.
# {'cluster_centers': array([[ 0.1152992 ],
#        [-0.02228158]]), 'assignments': array([103, 245, 234, ..., 249, 255, 118], dtype=uint8), 'data_shape': (30000,)} [[ 0.1152992 ]
#  [-0.02228158]]
# K-Means converged in 21 iterations.
# {'cluster_centers': array([[-0.31979605],
#        [ 0.30718329]]), 'assignments': array([ 46,  10,  85, 255, 230,  21,   1, 219, 149,  58,   8, 121, 177,
#         83,  94, 168,  39, 215, 180,   8, 119,  31, 100, 118,  15,  96,
#        120, 252,  21,  21, 140, 167,  51,  28, 233, 255, 118, 208, 133,
#         73,  89, 105, 196,  45, 226, 145,  86, 242,  27, 155, 187, 131,
#        109, 224, 178, 120,  61,  53, 123,   2, 254, 175,  48], dtype=uint8), 'data_shape': (500,)} [[-0.31979605]
#  [ 0.30718329]]
# K-Means converged in 11 iterations.
# C-step #4 has finished.
# Lagrange multipliers have been updated.
# Train err: 1.96%, train loss: 0.05929567477153253
# TEST ERR: 3.44%, test loss: 0.10691436452063559
# 0.00011486534062500004
# L-step #5 with lr: 0.63274
# 	epoch #0 is finished.
# 	  avg. train loss: 0.055553
# 	epoch #1 is finished.
# 	  avg. train loss: 0.055038
# 	epoch #2 is finished.
# 	  avg. train loss: 0.054394
# 	epoch #3 is finished.
# 	  avg. train loss: 0.053689
# 	epoch #4 is finished.
# 	  avg. train loss: 0.052996
# 	epoch #5 is finished.
# 	  avg. train loss: 0.052279
# 	epoch #6 is finished.
# 	  avg. train loss: 0.051649
# from retrieve 130.31621068059886
# from retrieve 58.56300119051749
# from retrieve 32.59788327674382
# L-step #5 has finished.
# {'cluster_centers': array([[ 0.05321967],
#        [-0.02234721]]), 'assignments': array([179,  63, 190, ..., 238, 247, 118], dtype=uint8), 'data_shape': (235200,)} [[ 0.05321967]
#  [-0.02234721]]
# K-Means converged in 39 iterations.
# {'cluster_centers': array([[ 0.05133273],
#        [-0.08202067]]), 'assignments': array([ 70,   0, 162, ...,  64, 196,  36], dtype=uint8), 'data_shape': (30000,)} [[ 0.05133273]
#  [-0.08202067]]
# K-Means converged in 43 iterations.
# {'cluster_centers': array([[-0.28453603],
#        [ 0.36775226]]), 'assignments': array([ 58,  11,  19, 250, 192,  81,  21,  24, 178,  28,   8, 211, 129,
#         95,  25,  24, 187, 125,  52,  36,  68, 172,  33, 252, 142, 212,
#        160, 171,  53,  37, 142, 231, 223,  35, 101, 203, 202, 194, 101,
#        198, 177, 206, 180,  45, 166, 170, 132, 218,   0,  20, 207, 210,
#         54, 160,  12, 120, 139, 170,  12,  16,  20,   6,   0], dtype=uint8), 'data_shape': (500,)} [[-0.28453603]
#  [ 0.36775226]]
# K-Means converged in 7 iterations.
# C-step #5 has finished.
# Lagrange multipliers have been updated.
# Train err: 1.68%, train loss: 0.06015941258086715
# TEST ERR: 3.37%, test loss: 0.10475488688743431
# 0.00012060860765625005
# L-step #6 with lr: 0.62009
# 	epoch #0 is finished.
# 	  avg. train loss: 0.060490
# 	epoch #1 is finished.
# 	  avg. train loss: 0.059984
# 	epoch #2 is finished.
# 	  avg. train loss: 0.059267
# 	epoch #3 is finished.
# 	  avg. train loss: 0.058451
# 	epoch #4 is finished.
# 	  avg. train loss: 0.057677
# 	epoch #5 is finished.
# 	  avg. train loss: 0.056909
# 	epoch #6 is finished.
# 	  avg. train loss: 0.056136
# from retrieve 124.48045458865462
# from retrieve 58.22248169933498
# from retrieve 32.97552162378642
# L-step #6 has finished.
# {'cluster_centers': array([[ 0.03162784],
#        [-0.0300475 ]]), 'assignments': array([ 50, 201,  43, ..., 140, 157,  62], dtype=uint8), 'data_shape': (235200,)} [[ 0.03162784]
#  [-0.0300475 ]]
# K-Means converged in 11 iterations.
# {'cluster_centers': array([[ 0.08044206],
#        [-0.03852186]]), 'assignments': array([ 71,  68, 234, ..., 191, 209, 191], dtype=uint8), 'data_shape': (30000,)} [[ 0.08044206]
#  [-0.03852186]]
# K-Means converged in 17 iterations.
# {'cluster_centers': array([[-0.43582308],
#        [ 0.28269063]]), 'assignments': array([ 44, 222, 225, 255, 254,  25,   1, 255, 221,  59, 123, 123, 245,
#         51,  84, 237,  39, 211, 215, 204, 247, 255, 102,  86, 127, 104,
#        105, 252,  45, 151, 236, 167, 113,  84, 203, 247, 118, 210, 141,
#        241, 197,  96, 196, 109, 234,  25, 119, 255, 139, 155, 251, 130,
#        237, 236, 242, 124,  61,  20, 187, 167, 246, 174,  16], dtype=uint8), 'data_shape': (500,)} [[-0.43582308]
#  [ 0.28269063]]
# K-Means converged in 13 iterations.
# C-step #6 has finished.
# Lagrange multipliers have been updated.
# Train err: 2.96%, train loss: 0.08667562392561935
# TEST ERR: 4.64%, test loss: 0.15894745774795674
# 0.00012663903803906255
# L-step #7 with lr: 0.60769
# 	epoch #0 is finished.
# 	  avg. train loss: 0.055728
# 	epoch #1 is finished.
# 	  avg. train loss: 0.055227
# 	epoch #2 is finished.
# 	  avg. train loss: 0.054531
# 	epoch #3 is finished.
# 	  avg. train loss: 0.053852
# 	epoch #4 is finished.
# 	  avg. train loss: 0.053062
# 	epoch #5 is finished.
# 	  avg. train loss: 0.052362
# 	epoch #6 is finished.
# 	  avg. train loss: 0.051654
# from retrieve 124.02171548838874
# from retrieve 58.93902614723186
# from retrieve 35.272558407764365
# L-step #7 has finished.
# {'cluster_centers': array([[ 0.03068938],
#        [-0.03402147]]), 'assignments': array([163,  37,  44, ..., 142, 246,  52], dtype=uint8), 'data_shape': (235200,)} [[ 0.03068938]
#  [-0.03402147]]
# K-Means converged in 9 iterations.
# {'cluster_centers': array([[ 0.06273492],
#        [-0.05667609]]), 'assignments': array([ 70,  21, 226, ..., 232, 150,  50], dtype=uint8), 'data_shape': (30000,)} [[ 0.06273492]
#  [-0.05667609]]
# K-Means converged in 21 iterations.
# {'cluster_centers': array([[-0.169851 ],
#        [ 0.8938571]]), 'assignments': array([  0,   2,   0,  64,  64,  17,   1,   0,   0,  24,   8,  19,   1,
#         18,  16,   8,   2,   5,  20,   4,  68, 168,   0,  80,   4,  64,
#          0,  32,  53,   1, 132, 162,  80,   0,  64,  64,  64,  66,   0,
#        192, 145,   8, 128,  37,   2, 136,   0,  26,   0,  16, 203, 128,
#          4,  32,   0,  32,   8,  32,   0,   0,  20,   4,   0], dtype=uint8), 'data_shape': (500,)} [[-0.169851 ]
#  [ 0.8938571]]
# K-Means converged in 21 iterations.
# C-step #7 has finished.
# Lagrange multipliers have been updated.
# Train err: 0.50%, train loss: 0.020029914818068806
# TEST ERR: 2.13%, test loss: 0.0676043701104835
# 0.00013297098994101569
# L-step #8 with lr: 0.59553
# 	epoch #0 is finished.
# 	  avg. train loss: 0.053088
# 	epoch #1 is finished.
# 	  avg. train loss: 0.052588
# 	epoch #2 is finished.
# 	  avg. train loss: 0.051916
# 	epoch #3 is finished.
# 	  avg. train loss: 0.051243
# 	epoch #4 is finished.
# 	  avg. train loss: 0.050587
# 	epoch #5 is finished.
# 	  avg. train loss: 0.049839
# 	epoch #6 is finished.
# 	  avg. train loss: 0.049199
# from retrieve 123.82754157949462
# from retrieve 59.95437557130019
# from retrieve 36.694048799237734
# L-step #8 has finished.
# {'cluster_centers': array([[ 0.02725955],
#        [-0.03089029]]), 'assignments': array([ 48,  11, 186, ..., 140, 183,  54], dtype=uint8), 'data_shape': (235200,)} [[ 0.02725955]
#  [-0.03089029]]
# K-Means converged in 22 iterations.
# {'cluster_centers': array([[ 0.08035761],
#        [-0.03551114]]), 'assignments': array([ 71,  96, 170, ..., 113, 213,  38], dtype=uint8), 'data_shape': (30000,)} [[ 0.08035761]
#  [-0.03551114]]
# K-Means converged in 22 iterations.
# {'cluster_centers': array([[-0.48191204],
#        [ 0.2749336 ]]), 'assignments': array([ 62,  10,  87, 255, 230,  85,   5, 219, 183,  62,   8, 251, 177,
#         95,  93, 169, 191, 251, 180,  44, 119, 191, 101, 254, 139, 244,
#        232, 254,   5,  53, 142, 231, 255,  55, 237, 255, 254, 210, 229,
#        207, 169, 231, 180,  45, 230,  59, 214, 250,  27, 159, 255,  82,
#        123, 224, 190, 120, 191, 159,  63,  18, 254, 175,  48], dtype=uint8), 'data_shape': (500,)} [[-0.48191204]
#  [ 0.2749336 ]]
# K-Means converged in 12 iterations.
# C-step #8 has finished.
# Lagrange multipliers have been updated.
# Train err: 2.48%, train loss: 0.07179104790900105
# TEST ERR: 3.70%, test loss: 0.13927551978143934
# 0.00013961953943806646
# L-step #9 with lr: 0.58362
# 	epoch #0 is finished.
# 	  avg. train loss: 0.059467
# 	epoch #1 is finished.
# 	  avg. train loss: 0.058875
# 	epoch #2 is finished.
# 	  avg. train loss: 0.058176
# 	epoch #3 is finished.
# 	  avg. train loss: 0.057318
# 	epoch #4 is finished.
# 	  avg. train loss: 0.056488
# 	epoch #5 is finished.
# 	  avg. train loss: 0.055687
# 	epoch #6 is finished.
# 	  avg. train loss: 0.054841
# from retrieve 117.9858661556436
# from retrieve 59.90409946038416
# from retrieve 39.62762682777424
# L-step #9 has finished.
# {'cluster_centers': array([[ 0.01513703],
#        [-0.0479564 ]]), 'assignments': array([  2,  36,  12, ..., 132, 144,  32], dtype=uint8), 'data_shape': (235200,)} [[ 0.01513703]
#  [-0.0479564 ]]
# K-Means converged in 16 iterations.
# {'cluster_centers': array([[ 0.09496688],
#        [-0.02836956]]), 'assignments': array([102,  21, 234, ..., 238, 254, 255], dtype=uint8), 'data_shape': (30000,)} [[ 0.09496688]
#  [-0.02836956]]
# K-Means converged in 14 iterations.
# {'cluster_centers': array([[-0.25039181],
#        [ 0.581386  ]]), 'assignments': array([ 42,  10,  17, 234, 208,  17,   1,  24, 144,  24,   8,  17, 129,
#         19,  24,   8,  35,  85,  52,   0,  68, 236,  32, 116,  14,  64,
#         32, 168,  53,   7, 140, 167,  83,   0,  97, 203,  66, 194,   5,
#         64,  81,  72, 196,  45, 170, 152,   4, 218,   0,  16, 203, 130,
#         36, 168,   0, 120,   9,  32, 136,  32,  20,   6,   0], dtype=uint8), 'data_shape': (500,)} [[-0.25039181]
#  [ 0.581386  ]]
# K-Means converged in 7 iterations.
# C-step #9 has finished.
# Lagrange multipliers have been updated.
# Train err: 2.58%, train loss: 0.07143951068206351
# TEST ERR: 3.99%, test loss: 0.14355020943594857
# 0.00014660051640996978
# L-step #10 with lr: 0.57195
# 	epoch #0 is finished.
# 	  avg. train loss: 0.053664
# 	epoch #1 is finished.
# 	  avg. train loss: 0.053037
# 	epoch #2 is finished.
# 	  avg. train loss: 0.052272
# 	epoch #3 is finished.
# 	  avg. train loss: 0.051492
# 	epoch #4 is finished.
# 	  avg. train loss: 0.050690
# 	epoch #5 is finished.
# 	  avg. train loss: 0.049963
# 	epoch #6 is finished.
# 	  avg. train loss: 0.049210
# from retrieve 118.9017941190897
# from retrieve 61.46280702987136
# from retrieve 40.47004064226749
# L-step #10 has finished.
# {'cluster_centers': array([[ 0.03818141],
#        [-0.02660811]]), 'assignments': array([179, 201,  42, ..., 142, 247, 118], dtype=uint8), 'data_shape': (235200,)} [[ 0.03818141]
#  [-0.02660811]]
# K-Means converged in 12 iterations.
# {'cluster_centers': array([[ 0.06363898],
#        [-0.05923441]]), 'assignments': array([ 71,  68, 226, ..., 249, 193,  52], dtype=uint8), 'data_shape': (30000,)} [[ 0.06363898]
#  [-0.05923441]]
# K-Means converged in 13 iterations.
# {'cluster_centers': array([[-0.12722792],
#        [ 0.8264195 ]]), 'assignments': array([  0,  10,   0,  80,  64,  17,   1,   0,   0,  24,   8,  82, 129,
#         82,  16,   8,   0,   1,  20,   4,  68,  12,   0,  80,   2,  64,
#          0,   0,   5,   1, 132, 162,  16,   0,   0, 192,  64,   0,   0,
#        192, 129,   0, 128,  37,   2,   0,   0, 144,   0,  16, 131, 128,
#          4,  32,   0,  32,   8,   0,   0,   0,  20,   4,   0], dtype=uint8), 'data_shape': (500,)} [[-0.12722792]
#  [ 0.8264195 ]]
# K-Means converged in 9 iterations.
# C-step #10 has finished.
# Lagrange multipliers have been updated.
# Train err: 0.40%, train loss: 0.017447639181632404
# TEST ERR: 1.88%, test loss: 0.06267964892348385
# 0.0001539305422304683
# L-step #11 with lr: 0.56051
# 	epoch #0 is finished.
# 	  avg. train loss: 0.052057
# 	epoch #1 is finished.
# 	  avg. train loss: 0.051534
# 	epoch #2 is finished.
# 	  avg. train loss: 0.050859
# 	epoch #3 is finished.
# 	  avg. train loss: 0.050091
# 	epoch #4 is finished.
# 	  avg. train loss: 0.049340
# 	epoch #5 is finished.
# 	  avg. train loss: 0.048597
# 	epoch #6 is finished.
# 	  avg. train loss: 0.047800
# from retrieve 117.65108759708596
# from retrieve 62.51655351245055
# from retrieve 41.504254050296474
# L-step #11 has finished.
# {'cluster_centers': array([[ 0.03542362],
#        [-0.02458285]]), 'assignments': array([ 50,  63, 190, ..., 236, 183,  54], dtype=uint8), 'data_shape': (235200,)} [[ 0.03542362]
#  [-0.02458285]]
# K-Means converged in 16 iterations.
# {'cluster_centers': array([[ 0.06430582],
#        [-0.05113957]]), 'assignments': array([ 70,   0, 162, ...,  64, 212,  34], dtype=uint8), 'data_shape': (30000,)} [[ 0.06430582]
#  [-0.05113957]]
# K-Means converged in 16 iterations.
# {'cluster_centers': array([[-0.68109986],
#        [ 0.24514338]]), 'assignments': array([ 62, 219, 243, 255, 238,  81,   5, 251, 255,  63, 107, 251, 241,
#         31,  95, 253, 191, 255, 247, 236, 247, 191, 101, 254, 175, 252,
#        249, 255,  61,  53, 174, 231, 255,  55, 237, 255, 254, 210, 237,
#        247, 245, 238, 244, 109, 230, 187, 215, 251,  11, 159, 255, 211,
#        255, 228, 254, 124, 191, 190, 127, 150, 246, 174,  16], dtype=uint8), 'data_shape': (500,)} [[-0.68109986]
#  [ 0.24514338]]
# K-Means converged in 8 iterations.
# C-step #11 has finished.
# Lagrange multipliers have been updated.
# Train err: 0.32%, train loss: 0.009806222927778266
# TEST ERR: 2.02%, test loss: 0.09206381497451377
# 0.00016162706934199172
# L-step #12 with lr: 0.54930
# 	epoch #0 is finished.
# 	  avg. train loss: 0.044518
# 	epoch #1 is finished.
# 	  avg. train loss: 0.043963
# 	epoch #2 is finished.
# 	  avg. train loss: 0.043283
# 	epoch #3 is finished.
# 	  avg. train loss: 0.042607
# 	epoch #4 is finished.
# 	  avg. train loss: 0.041879
# 	epoch #5 is finished.
# 	  avg. train loss: 0.041183
# 	epoch #6 is finished.
# 	  avg. train loss: 0.040509
# from retrieve 117.21440937983594
# from retrieve 62.94915987988357
# from retrieve 44.38596488562099
# L-step #12 has finished.
# {'cluster_centers': array([[ 0.02040873],
#        [-0.04021894]]), 'assignments': array([ 32,   1,  40, ..., 140, 148,  52], dtype=uint8), 'data_shape': (235200,)} [[ 0.02040873]
#  [-0.04021894]]
# K-Means converged in 12 iterations.
# {'cluster_centers': array([[ 0.09250952],
#        [-0.03001708]]), 'assignments': array([ 71, 117, 234, ..., 255, 215, 191], dtype=uint8), 'data_shape': (30000,)} [[ 0.09250952]
#  [-0.03001708]]
# K-Means converged in 15 iterations.
# {'cluster_centers': array([[-0.24249302],
#        [ 0.66476685]]), 'assignments': array([  8,  10,   1, 234, 192,  17,   1,  24, 144,  24,   8,  19, 129,
#         83,  16,   8,  35,  85,  20,   4,  68, 172,  32,  84,  14,  64,
#         32, 168,  37,   7, 140, 167,  81,   0,  65, 195,  66, 194,   5,
#        192, 145,  72, 132,  45, 162, 136,   4, 218,   0,  16, 203,   2,
#         32, 160,   0, 120,   9,   0,   8,   0,  20,   6,   0], dtype=uint8), 'data_shape': (500,)} [[-0.24249302]
#  [ 0.66476685]]
# K-Means converged in 12 iterations.
# C-step #12 has finished.
# Lagrange multipliers have been updated.
# Train err: 0.22%, train loss: 0.011137154066660838
# TEST ERR: 1.86%, test loss: 0.05659468396583949
# 0.0001697084228090913
# L-step #13 with lr: 0.53832
# 	epoch #0 is finished.
# 	  avg. train loss: 0.042505
# 	epoch #1 is finished.
# 	  avg. train loss: 0.042075
# 	epoch #2 is finished.
# 	  avg. train loss: 0.041443
# 	epoch #3 is finished.
# 	  avg. train loss: 0.040799
# 	epoch #4 is finished.
# 	  avg. train loss: 0.040188
# 	epoch #5 is finished.
# 	  avg. train loss: 0.039524
# 	epoch #6 is finished.
# 	  avg. train loss: 0.038915
# from retrieve 118.08018329894911
# from retrieve 63.63042812578833
# from retrieve 43.7796228051997
# L-step #13 has finished.
# {'cluster_centers': array([[ 0.03161029],
#        [-0.02538914]]), 'assignments': array([179,  45,  46, ..., 142, 247,  54], dtype=uint8), 'data_shape': (235200,)} [[ 0.03161029]
#  [-0.02538914]]
# K-Means converged in 16 iterations.
# {'cluster_centers': array([[ 0.0690454 ],
#        [-0.04797602]]), 'assignments': array([ 70,   4, 226, ..., 232, 252, 118], dtype=uint8), 'data_shape': (30000,)} [[ 0.0690454 ]
#  [-0.04797602]]
# K-Means converged in 13 iterations.
# {'cluster_centers': array([[-0.3161194 ],
#        [ 0.36462009]]), 'assignments': array([ 46,  10,  84,  95, 118,  21,   1, 203, 133,  58,   8, 123, 177,
#         19,  92, 168,  39, 131, 180,  12, 119, 255,  68, 114,  15,  96,
#         72, 244,  53,  17, 140, 163, 115,  20, 232, 254, 118,  82, 133,
#        193, 137,  97, 132,  37,  74,  25,  82, 250,  11, 155, 251, 128,
#        109, 104, 146,  40,  61,  53, 187,  34, 254, 175,  16], dtype=uint8), 'data_shape': (500,)} [[-0.3161194 ]
#  [ 0.36462009]]
# K-Means converged in 6 iterations.
# C-step #13 has finished.
# Lagrange multipliers have been updated.
# Train err: 0.31%, train loss: 0.009744153549721421
# TEST ERR: 1.76%, test loss: 0.07183755099285843
# 0.0001781938439495459
# L-step #14 with lr: 0.52755
# 	epoch #0 is finished.
# 	  avg. train loss: 0.046904
# 	epoch #1 is finished.
# 	  avg. train loss: 0.046319
# 	epoch #2 is finished.
# 	  avg. train loss: 0.045646
# 	epoch #3 is finished.
# 	  avg. train loss: 0.044839
# 	epoch #4 is finished.
# 	  avg. train loss: 0.044047
# 	epoch #5 is finished.
# 	  avg. train loss: 0.043271
# 	epoch #6 is finished.
# 	  avg. train loss: 0.042498
# from retrieve 112.6331283033452
# from retrieve 63.92889716878346
# from retrieve 45.66319077823363
# L-step #14 has finished.
# {'cluster_centers': array([[ 0.0209469 ],
#        [-0.03169501]]), 'assignments': array([ 34, 195, 152, ..., 132, 178,  52], dtype=uint8), 'data_shape': (235200,)} [[ 0.0209469 ]
#  [-0.03169501]]
# K-Means converged in 17 iterations.
# {'cluster_centers': array([[ 0.07514941],
#        [-0.03928376]]), 'assignments': array([ 71,  84, 170, ..., 113, 211,  38], dtype=uint8), 'data_shape': (30000,)} [[ 0.07514941]
#  [-0.03928376]]
# K-Means converged in 14 iterations.
# {'cluster_centers': array([[-0.21187314],
#        [ 0.75361943]]), 'assignments': array([ 32,  10,   1, 224, 192,  17,   1,  16,  16,  24,   8,  19, 129,
#         18,  16,   8,   2,  85,  20,   4,  68, 172,  32,  84,   6,  64,
#         32,  40,   5,   5, 132, 166,  80,   0,  65, 193,  64, 194,   0,
#        192, 145,   8, 128,  45, 162, 136,   4, 154,   0,  16, 203, 130,
#          4, 160,   0, 112,   8,  32,   0,   0,  20,   4,   0], dtype=uint8), 'data_shape': (500,)} [[-0.21187314]
#  [ 0.75361943]]
# K-Means converged in 4 iterations.
# C-step #14 has finished.
# Lagrange multipliers have been updated.
# Train err: 0.35%, train loss: 0.011667058543237142
# TEST ERR: 1.88%, test loss: 0.06010652421107077
# 0.0001871035361470232
# L-step #15 with lr: 0.51700
# 	epoch #0 is finished.
# 	  avg. train loss: 0.043420
# 	epoch #1 is finished.
# 	  avg. train loss: 0.042925
# 	epoch #2 is finished.
# 	  avg. train loss: 0.042296
# 	epoch #3 is finished.
# 	  avg. train loss: 0.041481
# 	epoch #4 is finished.
# 	  avg. train loss: 0.040740
# 	epoch #5 is finished.
# 	  avg. train loss: 0.039994
# 	epoch #6 is finished.
# 	  avg. train loss: 0.039345
# from retrieve 113.5347371438149
# from retrieve 63.84003794460793
# from retrieve 45.307002018394755
# L-step #15 has finished.
# {'cluster_centers': array([[ 0.02816751],
#        [-0.02932292]]), 'assignments': array([ 50,  45,  46, ..., 140, 183,  54], dtype=uint8), 'data_shape': (235200,)} [[ 0.02816751]
#  [-0.02932292]]
# K-Means converged in 20 iterations.
# {'cluster_centers': array([[ 0.07196809],
#        [-0.04011083]]), 'assignments': array([ 70,   1, 226, ..., 238, 212, 191], dtype=uint8), 'data_shape': (30000,)} [[ 0.07196809]
#  [-0.04011083]]
# K-Means converged in 25 iterations.
# {'cluster_centers': array([[-0.17606468],
#        [ 0.62094601]]), 'assignments': array([ 10,   2,   0,  90,  64,  17,   1,   8, 128,  24,   8,  81,   1,
#         83,  16,   8,  35,   1,  52,   0,  68, 168,   0, 112,  10,  64,
#          0, 160,  53,   1, 140, 163,  83,   0,  96, 202,  66,  66,   5,
#         64,  65,  64, 196,  37,   2,  24,   0,  90,   0,  16, 203, 128,
#         36,  32,  32,  40,   9,  16,   8,   0,  20,   6,   0], dtype=uint8), 'data_shape': (500,)} [[-0.17606468]
#  [ 0.62094601]]
# K-Means converged in 6 iterations.
# C-step #15 has finished.
# Lagrange multipliers have been updated.
# Train err: 0.56%, train loss: 0.0175223767786294
# TEST ERR: 2.27%, test loss: 0.08340881795056758
# 0.00019645871295437433
# L-step #16 with lr: 0.50666
# 	epoch #0 is finished.
# 	  avg. train loss: 0.049279
# 	epoch #1 is finished.
# 	  avg. train loss: 0.048649
# 	epoch #2 is finished.
# 	  avg. train loss: 0.047810
# 	epoch #3 is finished.
# 	  avg. train loss: 0.046934
# 	epoch #4 is finished.
# 	  avg. train loss: 0.046055
# 	epoch #5 is finished.
# 	  avg. train loss: 0.045189
# 	epoch #6 is finished.
# 	  avg. train loss: 0.044394
# from retrieve 110.37130190565182
# from retrieve 63.53951984186515
# from retrieve 45.010212993100936
# L-step #16 has finished.
# {'cluster_centers': array([[ 0.02413321],
#        [-0.02762099]]), 'assignments': array([179,   9,  40, ..., 142, 213,  52], dtype=uint8), 'data_shape': (235200,)} [[ 0.02413321]
#  [-0.02762099]]
# K-Means converged in 11 iterations.
# {'cluster_centers': array([[ 0.0687322 ],
#        [-0.04351354]]), 'assignments': array([ 71,  68, 226, ..., 249, 213,  50], dtype=uint8), 'data_shape': (30000,)} [[ 0.0687322 ]
#  [-0.04351354]]
# K-Means converged in 15 iterations.
# {'cluster_centers': array([[-0.56568361],
#        [ 0.31108934]]), 'assignments': array([ 60,  10, 211, 255, 246,  81,   5, 219, 247,  62,  10, 251, 177,
#         31,  93, 173, 191, 255, 181,  44, 119, 255, 101, 222, 143, 244,
#        232, 254,  53,  55, 142, 231, 253,  55, 205, 247, 254, 210, 229,
#        215, 177, 238, 180,  45, 238, 171, 214, 250,  11, 159, 255, 210,
#        127, 224, 222, 120, 191, 174, 191,  50, 246, 174,  16], dtype=uint8), 'data_shape': (500,)} [[-0.56568361]
#  [ 0.31108934]]
# K-Means converged in 7 iterations.
# C-step #16 has finished.
# Lagrange multipliers have been updated.
# Train err: 0.27%, train loss: 0.007438332536221706
# TEST ERR: 1.64%, test loss: 0.07234375534735331
# 0.00020628164860209307
# L-step #17 with lr: 0.49653
# 	epoch #0 is finished.
# 	  avg. train loss: 0.044230
# 	epoch #1 is finished.
# 	  avg. train loss: 0.043610
# 	epoch #2 is finished.
# 	  avg. train loss: 0.042835
# 	epoch #3 is finished.
# 	  avg. train loss: 0.041973
# 	epoch #4 is finished.
# 	  avg. train loss: 0.041143
# 	epoch #5 is finished.
# 	  avg. train loss: 0.040294
# 	epoch #6 is finished.
# 	  avg. train loss: 0.039510
# from retrieve 109.12600068951859
# from retrieve 63.22284950578823
# from retrieve 47.05358803098911
# L-step #17 has finished.
# {'cluster_centers': array([[ 0.02572003],
#        [-0.02730996]]), 'assignments': array([ 34,  39, 190, ..., 140, 182,  54], dtype=uint8), 'data_shape': (235200,)} [[ 0.02572003]
#  [-0.02730996]]
# K-Means converged in 27 iterations.
# {'cluster_centers': array([[ 0.07377914],
#        [-0.03938813]]), 'assignments': array([ 70,  52, 170, ...,  96, 230, 102], dtype=uint8), 'data_shape': (30000,)} [[ 0.07377914]
#  [-0.03938813]]
# K-Means converged in 14 iterations.
# {'cluster_centers': array([[-0.24475876],
#        [ 0.65097876]]), 'assignments': array([ 34,  10,   1, 234, 192,  17,   1,  16,  16,  24,   8,  19, 129,
#         83,  16,   8,  35,  81,  20,   4,  68, 172,  32, 116,   6,  64,
#         32, 168,  37,   5, 140, 166,  83,   0,  97, 203,  64, 194,   5,
#        192, 145,   8, 192,  45, 162, 152,   4, 218,   0,  16, 203, 130,
#         36, 168,   0, 120,   9,  48,   8,   0,  20,   6,   0], dtype=uint8), 'data_shape': (500,)} [[-0.24475876]
#  [ 0.65097876]]
# K-Means converged in 4 iterations.
# C-step #17 has finished.
# Lagrange multipliers have been updated.
# Train err: 0.80%, train loss: 0.023457196123840274
# TEST ERR: 2.21%, test loss: 0.08655219103356325
# 0.00021659573103219773
# L-step #18 with lr: 0.48659
# 	epoch #0 is finished.
# 	  avg. train loss: 0.048313
# 	epoch #1 is finished.
# 	  avg. train loss: 0.047670
# 	epoch #2 is finished.
# 	  avg. train loss: 0.046786
# 	epoch #3 is finished.
# 	  avg. train loss: 0.045876
# 	epoch #4 is finished.
# 	  avg. train loss: 0.044983
# 	epoch #5 is finished.
# 	  avg. train loss: 0.044061
# 	epoch #6 is finished.
# 	  avg. train loss: 0.043224
# from retrieve 106.44667959313557
# from retrieve 62.84226699581077
# from retrieve 46.821673454208934
# L-step #18 has finished.
# {'cluster_centers': array([[ 0.02283893],
#        [-0.02721742]]), 'assignments': array([ 49,  73,  42, ..., 140, 183,  54], dtype=uint8), 'data_shape': (235200,)} [[ 0.02283893]
#  [-0.02721742]]
# K-Means converged in 17 iterations.
# {'cluster_centers': array([[ 0.07932711],
#        [-0.03506973]]), 'assignments': array([ 87,  71, 226, ..., 255, 221, 191], dtype=uint8), 'data_shape': (30000,)} [[ 0.07932711]
#  [-0.03506973]]
# K-Means converged in 18 iterations.
# {'cluster_centers': array([[-0.16234914],
#        [ 0.72374492]]), 'assignments': array([  8,  10,  16,  80,  64,  17,   1,   8, 128,  24,   8,  83, 129,
#         18,  24,   8,   2,   5,  20,   4,  68, 172,   0,  80,  10,  64,
#          0,  32,   5,   1, 132, 163,  80,   0,  64, 192,  66,  66,   0,
#        192, 193,  64, 132,  37,   2,   8,   0, 154,   0,  16, 203, 128,
#          4,  32,   0,  32,   8,   0,   0,   0,  20,   4,   0], dtype=uint8), 'data_shape': (500,)} [[-0.16234914]
#  [ 0.72374492]]
# K-Means converged in 5 iterations.
# C-step #18 has finished.
# Lagrange multipliers have been updated.
# Train err: 0.07%, train loss: 0.005477644302773961
# TEST ERR: 1.53%, test loss: 0.05219235932778239
# 0.00022742551758380764
# L-step #19 with lr: 0.47686
# 	epoch #0 is finished.
# 	  avg. train loss: 0.051234
# 	epoch #1 is finished.
# 	  avg. train loss: 0.050485
# 	epoch #2 is finished.
# 	  avg. train loss: 0.049567
# 	epoch #3 is finished.
# 	  avg. train loss: 0.048563
# 	epoch #4 is finished.
# 	  avg. train loss: 0.047596
# 	epoch #5 is finished.
# 	  avg. train loss: 0.046524
# 	epoch #6 is finished.
# 	  avg. train loss: 0.045536
# from retrieve 103.97805140794794
# from retrieve 62.392018503612164
# from retrieve 47.28495554298688
# L-step #19 has finished.
# {'cluster_centers': array([[ 0.02917307],
#        [-0.02286128]]), 'assignments': array([178, 173,  44, ..., 206, 247,  52], dtype=uint8), 'data_shape': (235200,)} [[ 0.02917307]
#  [-0.02286128]]
# K-Means converged in 41 iterations.
# {'cluster_centers': array([[ 0.06146232],
#        [-0.05053528]]), 'assignments': array([ 70,   0, 226, ..., 232, 210,  54], dtype=uint8), 'data_shape': (30000,)} [[ 0.06146232]
#  [-0.05053528]]
# K-Means converged in 14 iterations.
# {'cluster_centers': array([[-0.38050383],
#        [ 0.38850773]]), 'assignments': array([ 46,  10,  65, 239, 230,  17,   1, 219, 149,  58,   8,  59, 177,
#         19,  84, 169,  39, 215, 180,  12, 119, 191, 100, 118,  15,  96,
#        104, 252,  53,  23, 140, 167, 115,  20, 233, 255, 118, 210, 133,
#        193, 145, 104, 132,  45, 226, 153,  86, 250,  11, 155, 251, 130,
#        109, 224, 178, 120,  61,  52,  59,   2, 246, 174,  16], dtype=uint8), 'data_shape': (500,)} [[-0.38050383]
#  [ 0.38850773]]
# K-Means converged in 8 iterations.
# C-step #19 has finished.
# Lagrange multipliers have been updated.
# Train err: 0.10%, train loss: 0.004227890102409346
# TEST ERR: 1.47%, test loss: 0.06867982350244113
# Compressed_params: 265706
# Compression_ratio: 30.57760956517999

# %% [markdown]
# ### Low-rank compression with automatic rank selection

# %%
parameters={'batch_size': 256, 'lr': 0.2, 'gamma': 0.9, 'step_size': 2, 'momentum': 0.9, 'weight_decay': 0, 'nesterov': True}
net = Net().cuda()
net.load_state_dict(torch.load("/content/state_dicts/" + str(parameters) + ".pt"))

layers = [lambda x=x: getattr(x, 'weight') for x in net.modules() if isinstance(x, nn.Linear)]
# ----------------- alpha - compresssion parameter
alpha=1e-9
alpha=1e-3
# ------------------------------------------------
compression_tasks = {
    Param(layers[0], device): (AsIs, RankSelection(conv_scheme='scheme_1', alpha=alpha, criterion='storage', module=layers[0], normalize=True), "layer1_lr"),
    Param(layers[1], device): (AsIs, RankSelection(conv_scheme='scheme_1', alpha=alpha, criterion='storage', module=layers[1], normalize=True), "layer2_lr"),
    Param(layers[2], device): (AsIs, RankSelection(conv_scheme='scheme_1', alpha=alpha, criterion='storage', module=layers[2], normalize=True), "layer3_lr")
}

lc_alg = lc.Algorithm(
    model=net,                            # model to compress
    compression_tasks=compression_tasks,  # specifications of compression
    l_step_optimization=my_l_step,        # implementation of L-step
    mu_schedule=mu_s,                     # schedule of mu values
    evaluation_func=train_test_acc_eval_f # evaluation function
)
lc_alg.run()
print('Compressed_params:', lc_alg.count_params())
print('Compression_ratio:', compute_compression_ratio(lc_alg))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-826f89f26ad8> in <module>()
#      18     compression_tasks=compression_tasks,  # specifications of compression
#      19     l_step_optimization=my_l_step,        # implementation of L-step
# ---> 20     mu_schedule=mu_s,                     # schedule of mu values
#      21     evaluation_func=train_test_acc_eval_f # evaluation function
#      22 )
#
# NameError: name 'mu_s' is not defined

# %% [markdown]
# ## Plots

# %%
# Pruning
train_errs_p = [0, 0, 0, 0, 0, 0, 0, 0]
test_errs_p = [.0125, .0125, .0121, .0121, .0123, .0119, .0117, .0133]
params_p = [46250, 36700, 26700, 16700, 13000, 10000, 8350, 6700]
ratios_p = [5.001867911627809, 6.207001113787051, 8.354945054945055, 12.976122810038508, 16.31688875092455, 
            20.78356715383339, 24.467737857159275, 29.934964951381907]

# Quantization
train_errs_q = [0, 0, 0, 0, 0, 0]
test_errs_q = [.0131, .0131, .0131, .0133, .0137, .0145]
params_q = [265892, 265796, 265748, 265724, 265712, 265706]
codebook_size = [64, 32, 16, 8, 4, 2]
ratios_q = [5.278211669964247, 6.333326391636644, 7.904382825147406, 10.50205468977391, 15.631856431644955, 
            30.537202530374536]

# Low-Rank
train_errs_l = [0, 0, 0, 0, .7845]
test_errs_l = [.0125, .0137, .0137, .0135, .7898]
params_l = [51625, 30037, 23869, 16512, 7840]
ratios_l = [5.114453200076879, 8.7413770448722164, 10.962552525335756, 15.730034876160076, 32.274711946634326]

# %%
train_errs = [train_errs_p, train_errs_q, train_errs_l]
test_errs = [test_errs_p, test_errs_q, test_errs_l]

params = [params_p, params_q, params_l]
ratios = [ratios_p, ratios_q, ratios_l]

compression_type = ["Pruning", "Quantization", "Low-Rank"]

x_axis = [params, ratios]
x_axis_labels = ["Number of Compressed Parameters", "Compression Ratio"]
y_axis = [train_errs, test_errs]
y_axis_labels = ["Train", "Test"]
legend = {"Pruning": "bo-", "Quantization": "ro-", "Low-Rank": "go-"}

from matplotlib import pyplot as plt
# hline - reference network error
x_max = [300000, 32]
train_test_errs = [0, .0133]
for curr_subset in range(2): # Train and test
    for curr_x in range(2): # Compressed Params and Compression Ratio
        fig = plt.figure()
        ax = plt.gca()
        ax.hlines(y=train_test_errs[curr_subset], xmin=0, xmax=x_max[curr_x], color='k', linestyles='dashed', label="Uncompressed Reference Network")
        for curr_type in range(3):
            ax.plot(x_axis[curr_x][curr_type], y_axis[curr_subset][curr_type], legend[compression_type[curr_type]], label=compression_type[curr_type])
            ax.set_xlabel(x_axis_labels[curr_x])
            ax.set_title(y_axis_labels[curr_subset] + ' Error vs. ' + x_axis_labels[curr_x])
            ax.set_ylabel(y_axis_labels[curr_subset] + ' Error')
            ax.set_xscale('log')
            ax.set_yscale('logit')
        ax.legend()

for curr_subset, errs in enumerate([train_errs_q, test_errs_q]):
    fig = plt.figure()
    ax = plt.gca()
    ax.hlines(y=train_test_errs[curr_subset], xmin=0, xmax=65, color='k', linestyles='dashed', label="Uncompressed Reference Network")
    ax.plot(codebook_size, errs, 'ro-', label="Quantization")
    ax.set_xlabel("Codebook Size")
    ax.set_title(y_axis_labels[curr_subset] + ' Error vs. Codebook Size (Quantization)')
    ax.set_ylabel(y_axis_labels[curr_subset] + ' Error')
    ax.set_xscale('linear')
    ax.set_yscale('linear')
    ax.legend()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:30: UserWarning: Data has no values between 0 and 1, and therefore cannot be logit-scaled.

# %%
from sklearn.metrics import confusion_matrix

net = Net().cuda()
net.load_state_dict(torch.load("model.pt"))

_, _, test_loader = data_loader(batch_size=10000, n_workers=0)
test_set, test_labels = next(iter(test_loader))

out = net(test_set.to(torch.device('cuda')))
_, preds = out.max(1)

labels = [0, 2, 5, 6, 7]

conf_matrix = confusion_matrix(y_true=test_labels.numpy(), y_pred=preds.cpu().detach().numpy())

fig, ax = plt.subplots(figsize=(7.5, 7.5))
ax.matshow(conf_matrix)
for i in range(conf_matrix.shape[0]):
    for j in range(conf_matrix.shape[1]):
        ax.text(x=j, y=i,s=conf_matrix[i, j], va='center', ha='center', size='xx-large')
 
plt.xlabel('Predictions', fontsize=18)
plt.ylabel('Actuals', fontsize=18)
plt.title('Confusion Matrix', fontsize=18)
ax.set_xticklabels(['']+labels)
ax.set_yticklabels(['']+labels)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-dab9170fb870> in <module>()
#       1 from sklearn.metrics import confusion_matrix
#       2
# ----> 3 net = Net().cuda()
#       4 net.load_state_dict(torch.load("model.pt"))
#       5
#
# NameError: name 'Net' is not defined
